# %%
import pandas as pd
import numpy as np
from pybaseball import statcast
from pybaseball import pitching_stats
from sklearn.model_selection import train_test_split
from catboost import CatBoostRegressor
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
#Read in data
data20_22 = pd.read_csv("Statcast_2020_to_2022.csv")
data_today = statcast()

#Select columns
data20_22 = data20_22[['player_name','pitch_type','release_speed','release_pos_x','release_pos_z','release_spin_rate','release_extension','spin_axis','pfx_x', 'pfx_z','vx0','vy0','vz0','ax','ay','az','game_year','delta_run_exp']]
data_today = data_today[['player_name','pitch_type','release_speed','release_pos_x','release_pos_z','release_spin_rate','release_extension','spin_axis','pfx_x', 'pfx_z','vx0','vy0','vz0','ax','ay','az','game_year','delta_run_exp']]

#Drop na values
data20_22 = data20_22.dropna()
data_today = data_today.dropna()

#Flip to get view from pitcher
data20_22['pfx_x'] = data20_22['pfx_x'] * -1
data_today['pfx_x'] = data_today['pfx_x'] * -1

#Change to inches
data20_22['pfx_x'] = data20_22['pfx_x'] * 12
data20_22['pfx_z'] = data20_22['pfx_z'] * 12
data_today['pfx_x'] = data_today['pfx_x'] * 12
data_today['pfx_z'] = data_today['pfx_z'] * 12

#Remove unnecessary pitches
data20_22 = data20_22[data20_22.pitch_type != 'PO']
data_today = data_today[data_today.pitch_type != 'PO']

#Retag pitches
data20_22['pitch_type'] = data20_22['pitch_type'].replace(['FF','FA'], 'Fastball')
data_today['pitch_type'] = data_today['pitch_type'].replace(['FF','FA'], 'Fastball')

data20_22['pitch_type'] = data20_22['pitch_type'].replace(['SI'], 'Sinker')
data_today['pitch_type'] = data_today['pitch_type'].replace(['SI'], 'Sinker')

data20_22['pitch_type'] = data20_22['pitch_type'].replace(['FC'], 'Cutter')
data_today['pitch_type'] = data_today['pitch_type'].replace(['FC'], 'Cutter')

data20_22['pitch_type'] = data20_22['pitch_type'].replace(['SL'], 'Slider')
data_today['pitch_type'] = data_today['pitch_type'].replace(['SL'], 'Slider')

data20_22['pitch_type'] = data20_22['pitch_type'].replace(['ST'], 'Sweeper')
data_today['pitch_type'] = data_today['pitch_type'].replace(['ST'], 'Sweeper')

data20_22['pitch_type'] = data20_22['pitch_type'].replace(['CU','CS','SV','KC'], 'Curveball')
data_today['pitch_type'] = data_today['pitch_type'].replace(['CU','CS','SV','KC'], 'Curveball')

data20_22['pitch_type'] = data20_22['pitch_type'].replace(['CH','FO','EP','KN','SC'], 'Changeup')
data_today['pitch_type'] = data_today['pitch_type'].replace(['CH','FO','EP','KN','SC'], 'Changeup')

data20_22['pitch_type'] = data20_22['pitch_type'].replace(['FS'], 'Splitter')
data_today['pitch_type'] = data_today['pitch_type'].replace(['FS'], 'Splitter')
# Out:
# start_dt 2024-06-09
# end_dt 2024-06-10
# Warning: no date range supplied, assuming yesterday's date.
# This is a large query, it may take a moment to complete
#  50%|█████     | 1/2 [00:01<00:01,  1.43s/it]/Users/maxwassarman/miniconda3/envs/baseball/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# /Users/maxwassarman/miniconda3/envs/baseball/lib/python3.12/site-packages/pybaseball/statcast.py:85: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_data = pd.concat(dataframe_list, axis=0).convert_dtypes(convert_string=False)

# %%
#caculate vaa and haa
def approach_angles(df):
    yf = 17/12
    y0 = 50
    df['vy_f'] = -np.sqrt(df['vy0']**2 - (2 * df['ay'] * y0 - yf))
    df['t'] = (df['vy_f'] - df['vy0']) / df['ay']
    df['vz_f'] = df['vz0'] + (df['az'] * df['t'])
    df['vx_f'] = df['vx0'] + (df['ax'] * df['t'])

    df['vaa'] = -np.arctan(df['vz_f'] / df['vy_f']) * (180 / np.pi)
    df['haa'] = -np.arctan(df['vx_f'] / df['vy_f']) * (180 / np.pi)
    return df

data20_22 = approach_angles(data20_22)
data_today = approach_angles(data_today)


#caculate estimated axis differential and estimated spin efficiency
def axis_differential(df):
    df['inferred_spin_degree'] = np.arctan2(df['pfx_x'],df['pfx_z']) * (180 / np.pi)
    df['axis_dif'] = np.abs(df['inferred_spin_degree'] - df['spin_axis'])
    return df

data20_22 = axis_differential(data20_22)
data_today = axis_differential(data_today)


def find_most_common_fastball(df):
    fastball_types = df[df['pitch_type'].isin(['Fastball', 'Sinker', 'Cutter'])]
    most_common_fastball = fastball_types.groupby(['player_name', 'pitch_type']).size().reset_index(name='count')
    most_common_fastball = most_common_fastball.loc[most_common_fastball.groupby('player_name')['count'].idxmax()]
    most_common_fastball = most_common_fastball[['player_name', 'pitch_type']]
    most_common_fastball.rename(columns={'pitch_type': 'most_common_fastball'}, inplace=True)
    return most_common_fastball

def add_velocity_and_movement_diff(df):
    most_common_fastball = find_most_common_fastball(df)
    
    df = df.merge(most_common_fastball, on='player_name', how='left')
    
    avg_stats = df[df['pitch_type'] == df['most_common_fastball']].groupby('player_name')[['release_speed', 'pfx_x', 'pfx_z']].mean().reset_index()
    avg_stats.rename(columns={
        'release_speed': 'avg_fastball_velocity',
        'pfx_x': 'avg_fastball_pfx_x',
        'pfx_z': 'avg_fastball_pfx_z'
    }, inplace=True)
    
    df = df.merge(avg_stats, on='player_name', how='left')
    
    df['velocity_diff'] = df['avg_fastball_velocity'] - df['release_speed']
    df['horizontal_movement_diff'] = df['avg_fastball_pfx_x'] - df['pfx_x']
    df['vertical_movement_diff'] = df['avg_fastball_pfx_z'] - df['pfx_z']
    
    return df

data20_22 = add_velocity_and_movement_diff(data20_22)
data_today = add_velocity_and_movement_diff(data_today)

# %%
#Seperate pitches for different models
fastball_20_22 = data20_22[data20_22.pitch_type.isin(['Fastball'])]
fastball_23 = data_today[data_today.pitch_type.isin(['Fastball'])]

sinker_20_22 = data20_22[data20_22.pitch_type.isin(['Sinker'])]
sinker_23 = data_today[data_today.pitch_type.isin(['Sinker'])]

cutter_20_22 = data20_22[data20_22.pitch_type.isin(['Cutter'])]
cutter_23 = data_today[data_today.pitch_type.isin(['Cutter'])]

slider_20_22 = data20_22[data20_22.pitch_type.isin(['Slider'])]
slider_23 = data_today[data_today.pitch_type.isin(['Slider'])]

sweeper_20_22 = data20_22[data20_22.pitch_type.isin(['Sweeper'])]
sweeper_23 = data_today[data_today.pitch_type.isin(['Sweeper'])]

curveball_20_22 = data20_22[data20_22.pitch_type.isin(['Curveball'])]
curveball_23 = data_today[data_today.pitch_type.isin(['Curveball'])]

changeup_20_22 = data20_22[data20_22.pitch_type.isin(['Changeup'])]
changeup_23 = data_today[data_today.pitch_type.isin(['Changeup'])]

splitter_20_22 = data20_22[data20_22.pitch_type.isin(['Splitter'])]
splitter_23 = data_today[data_today.pitch_type.isin(['Splitter'])]

# %%
fastball_features = ['release_speed','release_pos_x','release_pos_z','release_extension','pfx_x', 'pfx_z','game_year', 'axis_dif']
non_fastball_features = ['release_speed','release_pos_x','release_pos_z','release_extension','pfx_x', 'pfx_z','game_year', 'axis_dif', 'velocity_diff', 'horizontal_movement_diff', 'vertical_movement_diff']

#Split into train and test

fastball_x = fastball_20_22[fastball_features]
fastball_y = fastball_20_22['delta_run_exp']

x_train_fastball, x_test_fastball, y_train_fastball, y_test_fastball = train_test_split(fastball_x, fastball_y, train_size = 0.75, random_state = 12345)

sinker_x = sinker_20_22[non_fastball_features]
sinker_y = sinker_20_22['delta_run_exp']

x_train_sinker, x_test_sinker, y_train_sinker, y_test_sinker = train_test_split(sinker_x, sinker_y, train_size=0.75, random_state=12345)

cutter_x = cutter_20_22[non_fastball_features]
cutter_y = cutter_20_22['delta_run_exp']

x_train_cutter, x_test_cutter, y_train_cutter, y_test_cutter = train_test_split(cutter_x, cutter_y, train_size=0.75, random_state=12345)

slider_x = slider_20_22[non_fastball_features]
slider_y = slider_20_22['delta_run_exp']

x_train_slider, x_test_slider, y_train_slider, y_test_slider = train_test_split(slider_x, slider_y, train_size=0.75, random_state=12345)

sweeper_x = sweeper_20_22[non_fastball_features]
sweeper_y = sweeper_20_22['delta_run_exp']

x_train_sweeper, x_test_sweeper, y_train_sweeper, y_test_sweeper = train_test_split(sweeper_x, sweeper_y, train_size=0.75, random_state=12345)

curveball_x = curveball_20_22[non_fastball_features]
curveball_y = curveball_20_22['delta_run_exp']

x_train_curveball, x_test_curveball, y_train_curveball, y_test_curveball = train_test_split(curveball_x, curveball_y, train_size=0.75, random_state=12345)

changeup_x = changeup_20_22[non_fastball_features]
changeup_y = changeup_20_22['delta_run_exp']

x_train_changeup, x_test_changeup, y_train_changeup, y_test_changeup = train_test_split(changeup_x, changeup_y, train_size=0.75, random_state=12345)

splitter_x = splitter_20_22[non_fastball_features]
splitter_y = splitter_20_22['delta_run_exp']

x_train_splitter, x_test_splitter, y_train_splitter, y_test_splitter = train_test_split(splitter_x, splitter_y, train_size=0.75, random_state=12345)

# %%
#Set params for catboost models (Random ones right now)
params = {
    'iterations': 500,
    'depth': 5,
    'learning_rate': 0.11, #manual checks with FIP corr both predictive and descriptive
    'random_seed': 12345    
}

#Train each model

#Fastball
fastball_model = CatBoostRegressor(**params)
fastball_model.fit(x_train_fastball, y_train_fastball)

#Sinker
sinker_model = CatBoostRegressor(**params)
sinker_model.fit(x_train_sinker, y_train_sinker)

#Cutter
cutter_model = CatBoostRegressor(**params)
cutter_model.fit(x_train_cutter, y_train_cutter)

#Slider
slider_model = CatBoostRegressor(**params)
slider_model.fit(x_train_slider, y_train_slider)

#Sweeper
sweeper_model = CatBoostRegressor(**params)
sweeper_model.fit(x_train_sweeper, y_train_sweeper)

#Curveball
curveball_model = CatBoostRegressor(**params)
curveball_model.fit(x_train_curveball, y_train_curveball)

#Changeup
changeup_model = CatBoostRegressor(**params)
changeup_model.fit(x_train_changeup, y_train_changeup)

#Splitter
splitter_model = CatBoostRegressor(**params)
splitter_model.fit(x_train_splitter, y_train_splitter)
# Out:
# 0:	learn: 0.2404873	total: 15.8ms	remaining: 7.87s
# 1:	learn: 0.2404745	total: 26.4ms	remaining: 6.57s
# 2:	learn: 0.2404591	total: 36.2ms	remaining: 5.99s
# 3:	learn: 0.2404464	total: 46.1ms	remaining: 5.71s
# 4:	learn: 0.2404332	total: 57.1ms	remaining: 5.65s
# 5:	learn: 0.2404242	total: 66.5ms	remaining: 5.47s
# 6:	learn: 0.2404160	total: 77.9ms	remaining: 5.49s
# 7:	learn: 0.2404067	total: 88.6ms	remaining: 5.45s
# 8:	learn: 0.2404001	total: 99.7ms	remaining: 5.44s
# 9:	learn: 0.2403924	total: 111ms	remaining: 5.43s
# 10:	learn: 0.2403857	total: 122ms	remaining: 5.41s
# 11:	learn: 0.2403801	total: 132ms	remaining: 5.37s
# 12:	learn: 0.2403733	total: 143ms	remaining: 5.36s
# 13:	learn: 0.2403668	total: 153ms	remaining: 5.32s
# 14:	learn: 0.2403613	total: 165ms	remaining: 5.32s
# 15:	learn: 0.2403568	total: 176ms	remaining: 5.33s
# 16:	learn: 0.2403509	total: 187ms	remaining: 5.32s
# 17:	learn: 0.2403466	total: 197ms	remaining: 5.29s
# 18:	learn: 0.2403410	total: 209ms	remaining: 5.28s
# 19:	learn: 0.2403378	total: 219ms	remaining: 5.25s
# 20:	learn: 0.2403331	total: 229ms	remaining: 5.22s
# 21:	learn: 0.2403289	total: 242ms	remaining: 5.25s
# 22:	learn: 0.2403259	total: 252ms	remaining: 5.23s
# 23:	learn: 0.2403205	total: 262ms	remaining: 5.2s
# 24:	learn: 0.2403153	total: 272ms	remaining: 5.17s
# 25:	learn: 0.2403115	total: 281ms	remaining: 5.13s
# 26:	learn: 0.2403092	total: 292ms	remaining: 5.12s
# 27:	learn: 0.2403067	total: 303ms	remaining: 5.1s
# 28:	learn: 0.2403054	total: 311ms	remaining: 5.05s
# 29:	learn: 0.2403036	total: 321ms	remaining: 5.02s
# 30:	learn: 0.2403000	total: 330ms	remaining: 4.99s
# 31:	learn: 0.2402968	total: 340ms	remaining: 4.97s
# 32:	learn: 0.2402937	total: 351ms	remaining: 4.97s
# 33:	learn: 0.2402927	total: 361ms	remaining: 4.95s
# 34:	learn: 0.2402906	total: 371ms	remaining: 4.93s
# 35:	learn: 0.2402868	total: 381ms	remaining: 4.91s
# 36:	learn: 0.2402844	total: 391ms	remaining: 4.89s
# 37:	learn: 0.2402824	total: 401ms	remaining: 4.87s
# 38:	learn: 0.2402807	total: 411ms	remaining: 4.85s
# 39:	learn: 0.2402794	total: 422ms	remaining: 4.85s
# 40:	learn: 0.2402779	total: 431ms	remaining: 4.82s
# 41:	learn: 0.2402754	total: 443ms	remaining: 4.83s
# 42:	learn: 0.2402730	total: 456ms	remaining: 4.84s
# 43:	learn: 0.2402698	total: 467ms	remaining: 4.84s
# 44:	learn: 0.2402685	total: 478ms	remaining: 4.83s
# 45:	learn: 0.2402653	total: 490ms	remaining: 4.84s
# 46:	learn: 0.2402614	total: 505ms	remaining: 4.87s
# 47:	learn: 0.2402571	total: 517ms	remaining: 4.87s
# 48:	learn: 0.2402543	total: 528ms	remaining: 4.86s
# 49:	learn: 0.2402532	total: 540ms	remaining: 4.86s
# 50:	learn: 0.2402500	total: 552ms	remaining: 4.86s
# 51:	learn: 0.2402462	total: 562ms	remaining: 4.84s
# 52:	learn: 0.2402437	total: 574ms	remaining: 4.84s
# 53:	learn: 0.2402391	total: 587ms	remaining: 4.84s
# 54:	learn: 0.2402358	total: 598ms	remaining: 4.84s
# 55:	learn: 0.2402318	total: 609ms	remaining: 4.83s
# 56:	learn: 0.2402306	total: 620ms	remaining: 4.82s
# 57:	learn: 0.2402287	total: 631ms	remaining: 4.81s
# 58:	learn: 0.2402252	total: 644ms	remaining: 4.81s
# 59:	learn: 0.2402221	total: 657ms	remaining: 4.82s
# 60:	learn: 0.2402199	total: 669ms	remaining: 4.82s
# 61:	learn: 0.2402158	total: 683ms	remaining: 4.82s
# 62:	learn: 0.2402111	total: 698ms	remaining: 4.84s
# 63:	learn: 0.2402076	total: 712ms	remaining: 4.85s
# 64:	learn: 0.2402064	total: 726ms	remaining: 4.86s
# 65:	learn: 0.2402036	total: 738ms	remaining: 4.85s
# 66:	learn: 0.2402010	total: 750ms	remaining: 4.84s
# 67:	learn: 0.2401983	total: 761ms	remaining: 4.83s
# 68:	learn: 0.2401962	total: 773ms	remaining: 4.83s
# 69:	learn: 0.2401947	total: 785ms	remaining: 4.82s
# 70:	learn: 0.2401918	total: 795ms	remaining: 4.8s
# 71:	learn: 0.2401902	total: 805ms	remaining: 4.79s
# 72:	learn: 0.2401872	total: 818ms	remaining: 4.78s
# 73:	learn: 0.2401847	total: 829ms	remaining: 4.77s
# 74:	learn: 0.2401809	total: 840ms	remaining: 4.76s
# 75:	learn: 0.2401763	total: 852ms	remaining: 4.75s
# 76:	learn: 0.2401754	total: 863ms	remaining: 4.74s
# 77:	learn: 0.2401744	total: 874ms	remaining: 4.73s
# 78:	learn: 0.2401736	total: 901ms	remaining: 4.8s
# 79:	learn: 0.2401698	total: 912ms	remaining: 4.79s
# 80:	learn: 0.2401675	total: 923ms	remaining: 4.77s
# 81:	learn: 0.2401649	total: 934ms	remaining: 4.76s
# 82:	learn: 0.2401629	total: 944ms	remaining: 4.74s
# 83:	learn: 0.2401601	total: 954ms	remaining: 4.72s
# 84:	learn: 0.2401592	total: 966ms	remaining: 4.72s
# 85:	learn: 0.2401568	total: 976ms	remaining: 4.7s
# 86:	learn: 0.2401549	total: 985ms	remaining: 4.68s
# 87:	learn: 0.2401521	total: 995ms	remaining: 4.66s
# 88:	learn: 0.2401493	total: 1s	remaining: 4.64s
# 89:	learn: 0.2401468	total: 1.01s	remaining: 4.63s
# 90:	learn: 0.2401447	total: 1.02s	remaining: 4.61s
# 91:	learn: 0.2401426	total: 1.03s	remaining: 4.59s
# 92:	learn: 0.2401400	total: 1.04s	remaining: 4.57s
# 93:	learn: 0.2401391	total: 1.05s	remaining: 4.55s
# 94:	learn: 0.2401365	total: 1.06s	remaining: 4.54s
# 95:	learn: 0.2401344	total: 1.08s	remaining: 4.53s
# 96:	learn: 0.2401310	total: 1.09s	remaining: 4.51s
# 97:	learn: 0.2401286	total: 1.1s	remaining: 4.51s
# 98:	learn: 0.2401244	total: 1.11s	remaining: 4.5s
# 99:	learn: 0.2401220	total: 1.12s	remaining: 4.48s
# 100:	learn: 0.2401187	total: 1.13s	remaining: 4.46s
# 101:	learn: 0.2401172	total: 1.14s	remaining: 4.45s
# 102:	learn: 0.2401155	total: 1.15s	remaining: 4.43s
# 103:	learn: 0.2401129	total: 1.16s	remaining: 4.42s
# 104:	learn: 0.2401106	total: 1.17s	remaining: 4.4s
# 105:	learn: 0.2401096	total: 1.18s	remaining: 4.39s
# 106:	learn: 0.2401065	total: 1.19s	remaining: 4.38s
# 107:	learn: 0.2401027	total: 1.2s	remaining: 4.36s
# 108:	learn: 0.2401014	total: 1.21s	remaining: 4.35s
# 109:	learn: 0.2400996	total: 1.22s	remaining: 4.33s
# 110:	learn: 0.2400952	total: 1.23s	remaining: 4.32s
# 111:	learn: 0.2400927	total: 1.24s	remaining: 4.31s
# 112:	learn: 0.2400908	total: 1.25s	remaining: 4.29s
# 113:	learn: 0.2400878	total: 1.26s	remaining: 4.28s
# 114:	learn: 0.2400850	total: 1.27s	remaining: 4.27s
# 115:	learn: 0.2400813	total: 1.29s	remaining: 4.26s
# 116:	learn: 0.2400808	total: 1.3s	remaining: 4.24s
# 117:	learn: 0.2400776	total: 1.31s	remaining: 4.23s
# 118:	learn: 0.2400753	total: 1.32s	remaining: 4.22s
# 119:	learn: 0.2400731	total: 1.33s	remaining: 4.21s
# 120:	learn: 0.2400712	total: 1.34s	remaining: 4.2s
# 121:	learn: 0.2400691	total: 1.35s	remaining: 4.2s
# 122:	learn: 0.2400675	total: 1.36s	remaining: 4.18s
# 123:	learn: 0.2400653	total: 1.38s	remaining: 4.17s
# 124:	learn: 0.2400625	total: 1.39s	remaining: 4.16s
# 125:	learn: 0.2400624	total: 1.39s	remaining: 4.14s
# 126:	learn: 0.2400620	total: 1.4s	remaining: 4.12s
# 127:	learn: 0.2400587	total: 1.42s	remaining: 4.11s
# 128:	learn: 0.2400563	total: 1.43s	remaining: 4.1s
# 129:	learn: 0.2400543	total: 1.44s	remaining: 4.09s
# 130:	learn: 0.2400519	total: 1.45s	remaining: 4.08s
# 131:	learn: 0.2400496	total: 1.46s	remaining: 4.07s
# 132:	learn: 0.2400469	total: 1.48s	remaining: 4.1s
# 133:	learn: 0.2400453	total: 1.5s	remaining: 4.1s
# 134:	learn: 0.2400440	total: 1.51s	remaining: 4.09s
# 135:	learn: 0.2400416	total: 1.52s	remaining: 4.08s
# 136:	learn: 0.2400382	total: 1.53s	remaining: 4.06s
# 137:	learn: 0.2400361	total: 1.54s	remaining: 4.04s
# 138:	learn: 0.2400346	total: 1.55s	remaining: 4.03s
# 139:	learn: 0.2400328	total: 1.56s	remaining: 4.01s
# 140:	learn: 0.2400324	total: 1.57s	remaining: 3.99s
# 141:	learn: 0.2400305	total: 1.58s	remaining: 3.98s
# 142:	learn: 0.2400302	total: 1.59s	remaining: 3.96s
# 143:	learn: 0.2400279	total: 1.6s	remaining: 3.95s
# 144:	learn: 0.2400260	total: 1.61s	remaining: 3.93s
# 145:	learn: 0.2400241	total: 1.61s	remaining: 3.92s
# 146:	learn: 0.2400237	total: 1.62s	remaining: 3.9s
# 147:	learn: 0.2400234	total: 1.63s	remaining: 3.88s
# 148:	learn: 0.2400202	total: 1.64s	remaining: 3.87s
# 149:	learn: 0.2400190	total: 1.65s	remaining: 3.86s
# 150:	learn: 0.2400177	total: 1.66s	remaining: 3.85s
# 151:	learn: 0.2400155	total: 1.67s	remaining: 3.83s
# 152:	learn: 0.2400152	total: 1.68s	remaining: 3.82s
# 153:	learn: 0.2400128	total: 1.69s	remaining: 3.8s
# 154:	learn: 0.2400121	total: 1.7s	remaining: 3.79s
# 155:	learn: 0.2400112	total: 1.71s	remaining: 3.77s
# 156:	learn: 0.2400075	total: 1.72s	remaining: 3.76s
# 157:	learn: 0.2400049	total: 1.73s	remaining: 3.75s
# 158:	learn: 0.2400015	total: 1.74s	remaining: 3.74s
# 159:	learn: 0.2399982	total: 1.75s	remaining: 3.72s
# 160:	learn: 0.2399950	total: 1.76s	remaining: 3.71s
# 161:	learn: 0.2399929	total: 1.77s	remaining: 3.7s
# 162:	learn: 0.2399917	total: 1.78s	remaining: 3.68s
# 163:	learn: 0.2399906	total: 1.79s	remaining: 3.67s
# 164:	learn: 0.2399904	total: 1.8s	remaining: 3.65s
# 165:	learn: 0.2399897	total: 1.81s	remaining: 3.64s
# 166:	learn: 0.2399890	total: 1.82s	remaining: 3.63s
# 167:	learn: 0.2399826	total: 1.83s	remaining: 3.61s
# 168:	learn: 0.2399792	total: 1.84s	remaining: 3.6s
# 169:	learn: 0.2399788	total: 1.85s	remaining: 3.59s
# 170:	learn: 0.2399782	total: 1.86s	remaining: 3.58s
# 171:	learn: 0.2399775	total: 1.87s	remaining: 3.57s
# 172:	learn: 0.2399755	total: 1.88s	remaining: 3.56s
# 173:	learn: 0.2399728	total: 1.89s	remaining: 3.54s
# 174:	learn: 0.2399711	total: 1.9s	remaining: 3.53s
# 175:	learn: 0.2399697	total: 1.91s	remaining: 3.52s
# 176:	learn: 0.2399671	total: 1.92s	remaining: 3.51s
# 177:	learn: 0.2399668	total: 1.93s	remaining: 3.49s
# 178:	learn: 0.2399611	total: 1.94s	remaining: 3.48s
# 179:	learn: 0.2399594	total: 1.95s	remaining: 3.46s
# 180:	learn: 0.2399541	total: 1.96s	remaining: 3.45s
# 181:	learn: 0.2399510	total: 1.97s	remaining: 3.44s
# 182:	learn: 0.2399487	total: 1.98s	remaining: 3.42s
# 183:	learn: 0.2399450	total: 1.99s	remaining: 3.41s
# 184:	learn: 0.2399421	total: 2s	remaining: 3.4s
# 185:	learn: 0.2399393	total: 2.01s	remaining: 3.39s
# 186:	learn: 0.2399372	total: 2.02s	remaining: 3.38s
# 187:	learn: 0.2399333	total: 2.03s	remaining: 3.37s
# 188:	learn: 0.2399316	total: 2.04s	remaining: 3.35s
# 189:	learn: 0.2399287	total: 2.05s	remaining: 3.34s
# 190:	learn: 0.2399262	total: 2.06s	remaining: 3.33s
# 191:	learn: 0.2399235	total: 2.07s	remaining: 3.31s
# 192:	learn: 0.2399213	total: 2.08s	remaining: 3.3s
# 193:	learn: 0.2399186	total: 2.09s	remaining: 3.29s
# 194:	learn: 0.2399169	total: 2.1s	remaining: 3.28s
# 195:	learn: 0.2399135	total: 2.11s	remaining: 3.27s
# 196:	learn: 0.2399099	total: 2.12s	remaining: 3.25s
# 197:	learn: 0.2399048	total: 2.13s	remaining: 3.24s
# 198:	learn: 0.2399027	total: 2.13s	remaining: 3.23s
# 199:	learn: 0.2398991	total: 2.14s	remaining: 3.22s
# 200:	learn: 0.2398960	total: 2.15s	remaining: 3.21s
# 201:	learn: 0.2398946	total: 2.16s	remaining: 3.19s
# 202:	learn: 0.2398909	total: 2.17s	remaining: 3.18s
# 203:	learn: 0.2398897	total: 2.19s	remaining: 3.17s
# 204:	learn: 0.2398881	total: 2.2s	remaining: 3.16s
# 205:	learn: 0.2398860	total: 2.21s	remaining: 3.15s
# 206:	learn: 0.2398845	total: 2.22s	remaining: 3.14s
# 207:	learn: 0.2398821	total: 2.23s	remaining: 3.13s
# 208:	learn: 0.2398799	total: 2.24s	remaining: 3.12s
# 209:	learn: 0.2398779	total: 2.25s	remaining: 3.11s
# 210:	learn: 0.2398776	total: 2.27s	remaining: 3.1s
# 211:	learn: 0.2398751	total: 2.28s	remaining: 3.1s
# 212:	learn: 0.2398717	total: 2.29s	remaining: 3.09s
# 213:	learn: 0.2398681	total: 2.3s	remaining: 3.08s
# 214:	learn: 0.2398651	total: 2.31s	remaining: 3.07s
# 215:	learn: 0.2398605	total: 2.33s	remaining: 3.06s
# 216:	learn: 0.2398603	total: 2.34s	remaining: 3.05s
# 217:	learn: 0.2398575	total: 2.35s	remaining: 3.04s
# 218:	learn: 0.2398539	total: 2.36s	remaining: 3.03s
# 219:	learn: 0.2398516	total: 2.37s	remaining: 3.02s
# 220:	learn: 0.2398490	total: 2.39s	remaining: 3.01s
# 221:	learn: 0.2398459	total: 2.4s	remaining: 3.01s
# 222:	learn: 0.2398432	total: 2.41s	remaining: 3s
# 223:	learn: 0.2398398	total: 2.42s	remaining: 2.99s
# 224:	learn: 0.2398359	total: 2.44s	remaining: 2.98s
# 225:	learn: 0.2398333	total: 2.45s	remaining: 2.97s
# 226:	learn: 0.2398318	total: 2.46s	remaining: 2.96s
# 227:	learn: 0.2398270	total: 2.47s	remaining: 2.95s
# 228:	learn: 0.2398245	total: 2.48s	remaining: 2.94s
# 229:	learn: 0.2398229	total: 2.5s	remaining: 2.93s
# 230:	learn: 0.2398216	total: 2.51s	remaining: 2.92s
# 231:	learn: 0.2398201	total: 2.52s	remaining: 2.91s
# 232:	learn: 0.2398175	total: 2.53s	remaining: 2.9s
# 233:	learn: 0.2398152	total: 2.54s	remaining: 2.89s
# 234:	learn: 0.2398134	total: 2.55s	remaining: 2.88s
# 235:	learn: 0.2398108	total: 2.57s	remaining: 2.87s
# 236:	learn: 0.2398079	total: 2.58s	remaining: 2.86s
# 237:	learn: 0.2398056	total: 2.59s	remaining: 2.85s
# 238:	learn: 0.2398026	total: 2.6s	remaining: 2.84s
# 239:	learn: 0.2397986	total: 2.61s	remaining: 2.83s
# 240:	learn: 0.2397955	total: 2.62s	remaining: 2.81s
# 241:	learn: 0.2397934	total: 2.63s	remaining: 2.8s
# 242:	learn: 0.2397908	total: 2.64s	remaining: 2.79s
# 243:	learn: 0.2397873	total: 2.65s	remaining: 2.78s
# 244:	learn: 0.2397870	total: 2.68s	remaining: 2.79s
# 245:	learn: 0.2397837	total: 2.7s	remaining: 2.79s
# 246:	learn: 0.2397819	total: 2.72s	remaining: 2.79s
# 247:	learn: 0.2397806	total: 2.73s	remaining: 2.78s
# 248:	learn: 0.2397794	total: 2.74s	remaining: 2.77s
# 249:	learn: 0.2397766	total: 2.75s	remaining: 2.75s
# 250:	learn: 0.2397752	total: 2.76s	remaining: 2.74s
# 251:	learn: 0.2397747	total: 2.77s	remaining: 2.73s
# 252:	learn: 0.2397701	total: 2.78s	remaining: 2.72s
# 253:	learn: 0.2397653	total: 2.79s	remaining: 2.71s
# 254:	learn: 0.2397635	total: 2.8s	remaining: 2.69s
# 255:	learn: 0.2397601	total: 2.81s	remaining: 2.68s
# 256:	learn: 0.2397599	total: 2.82s	remaining: 2.67s
# 257:	learn: 0.2397587	total: 2.83s	remaining: 2.65s
# 258:	learn: 0.2397584	total: 2.84s	remaining: 2.64s
# 259:	learn: 0.2397568	total: 2.85s	remaining: 2.63s
# 260:	learn: 0.2397532	total: 2.86s	remaining: 2.62s
# 261:	learn: 0.2397508	total: 2.87s	remaining: 2.61s
# 262:	learn: 0.2397475	total: 2.88s	remaining: 2.6s
# 263:	learn: 0.2397450	total: 2.89s	remaining: 2.58s
# 264:	learn: 0.2397434	total: 2.9s	remaining: 2.57s
# 265:	learn: 0.2397416	total: 2.91s	remaining: 2.56s
# 266:	learn: 0.2397406	total: 2.92s	remaining: 2.55s
# 267:	learn: 0.2397378	total: 2.94s	remaining: 2.55s
# 268:	learn: 0.2397353	total: 2.95s	remaining: 2.53s
# 269:	learn: 0.2397311	total: 2.96s	remaining: 2.52s
# 270:	learn: 0.2397293	total: 2.98s	remaining: 2.51s
# 271:	learn: 0.2397253	total: 2.98s	remaining: 2.5s
# 272:	learn: 0.2397245	total: 3s	remaining: 2.49s
# 273:	learn: 0.2397199	total: 3.01s	remaining: 2.48s
# 274:	learn: 0.2397175	total: 3.02s	remaining: 2.47s
# 275:	learn: 0.2397160	total: 3.02s	remaining: 2.46s
# 276:	learn: 0.2397144	total: 3.04s	remaining: 2.44s
# 277:	learn: 0.2397117	total: 3.04s	remaining: 2.43s
# 278:	learn: 0.2397089	total: 3.06s	remaining: 2.42s
# 279:	learn: 0.2397079	total: 3.07s	remaining: 2.41s
# 280:	learn: 0.2397061	total: 3.08s	remaining: 2.4s
# 281:	learn: 0.2397039	total: 3.09s	remaining: 2.39s
# 282:	learn: 0.2397003	total: 3.1s	remaining: 2.38s
# 283:	learn: 0.2396988	total: 3.11s	remaining: 2.37s
# 284:	learn: 0.2396986	total: 3.12s	remaining: 2.35s
# 285:	learn: 0.2396950	total: 3.13s	remaining: 2.34s
# 286:	learn: 0.2396938	total: 3.14s	remaining: 2.33s
# 287:	learn: 0.2396925	total: 3.15s	remaining: 2.32s
# 288:	learn: 0.2396897	total: 3.16s	remaining: 2.31s
# 289:	learn: 0.2396870	total: 3.17s	remaining: 2.29s
# 290:	learn: 0.2396856	total: 3.18s	remaining: 2.28s
# 291:	learn: 0.2396830	total: 3.19s	remaining: 2.27s
# 292:	learn: 0.2396819	total: 3.2s	remaining: 2.26s
# 293:	learn: 0.2396805	total: 3.21s	remaining: 2.25s
# 294:	learn: 0.2396770	total: 3.22s	remaining: 2.23s
# 295:	learn: 0.2396751	total: 3.23s	remaining: 2.22s
# 296:	learn: 0.2396737	total: 3.24s	remaining: 2.21s
# 297:	learn: 0.2396709	total: 3.25s	remaining: 2.2s
# 298:	learn: 0.2396689	total: 3.25s	remaining: 2.19s
# 299:	learn: 0.2396655	total: 3.27s	remaining: 2.18s
# 300:	learn: 0.2396621	total: 3.28s	remaining: 2.17s
# 301:	learn: 0.2396587	total: 3.29s	remaining: 2.16s
# 302:	learn: 0.2396576	total: 3.3s	remaining: 2.15s
# 303:	learn: 0.2396554	total: 3.31s	remaining: 2.13s
# 304:	learn: 0.2396528	total: 3.32s	remaining: 2.12s
# 305:	learn: 0.2396513	total: 3.33s	remaining: 2.11s
# 306:	learn: 0.2396489	total: 3.34s	remaining: 2.1s
# 307:	learn: 0.2396476	total: 3.35s	remaining: 2.09s
# 308:	learn: 0.2396439	total: 3.36s	remaining: 2.08s
# 309:	learn: 0.2396420	total: 3.37s	remaining: 2.06s
# 310:	learn: 0.2396398	total: 3.38s	remaining: 2.05s
# 311:	learn: 0.2396368	total: 3.39s	remaining: 2.04s
# 312:	learn: 0.2396348	total: 3.4s	remaining: 2.03s
# 313:	learn: 0.2396326	total: 3.41s	remaining: 2.02s
# 314:	learn: 0.2396303	total: 3.42s	remaining: 2.01s
# 315:	learn: 0.2396274	total: 3.43s	remaining: 2s
# 316:	learn: 0.2396254	total: 3.44s	remaining: 1.98s
# 317:	learn: 0.2396224	total: 3.45s	remaining: 1.97s
# 318:	learn: 0.2396203	total: 3.46s	remaining: 1.96s
# 319:	learn: 0.2396188	total: 3.47s	remaining: 1.95s
# 320:	learn: 0.2396168	total: 3.48s	remaining: 1.94s
# 321:	learn: 0.2396138	total: 3.49s	remaining: 1.93s
# 322:	learn: 0.2396114	total: 3.5s	remaining: 1.92s
# 323:	learn: 0.2396084	total: 3.51s	remaining: 1.91s
# 324:	learn: 0.2396067	total: 3.52s	remaining: 1.9s
# 325:	learn: 0.2396046	total: 3.53s	remaining: 1.89s
# 326:	learn: 0.2396038	total: 3.54s	remaining: 1.87s
# 327:	learn: 0.2396011	total: 3.55s	remaining: 1.86s
# 328:	learn: 0.2395992	total: 3.56s	remaining: 1.85s
# 329:	learn: 0.2395973	total: 3.57s	remaining: 1.84s
# 330:	learn: 0.2395948	total: 3.58s	remaining: 1.83s
# 331:	learn: 0.2395936	total: 3.59s	remaining: 1.82s
# 332:	learn: 0.2395917	total: 3.6s	remaining: 1.81s
# 333:	learn: 0.2395881	total: 3.61s	remaining: 1.79s
# 334:	learn: 0.2395846	total: 3.62s	remaining: 1.78s
# 335:	learn: 0.2395839	total: 3.63s	remaining: 1.77s
# 336:	learn: 0.2395818	total: 3.64s	remaining: 1.76s
# 337:	learn: 0.2395800	total: 3.65s	remaining: 1.75s
# 338:	learn: 0.2395768	total: 3.66s	remaining: 1.74s
# 339:	learn: 0.2395746	total: 3.67s	remaining: 1.73s
# 340:	learn: 0.2395723	total: 3.69s	remaining: 1.72s
# 341:	learn: 0.2395702	total: 3.69s	remaining: 1.71s
# 342:	learn: 0.2395683	total: 3.71s	remaining: 1.7s
# 343:	learn: 0.2395655	total: 3.71s	remaining: 1.68s
# 344:	learn: 0.2395635	total: 3.73s	remaining: 1.67s
# 345:	learn: 0.2395600	total: 3.74s	remaining: 1.66s
# 346:	learn: 0.2395590	total: 3.75s	remaining: 1.65s
# 347:	learn: 0.2395576	total: 3.76s	remaining: 1.64s
# 348:	learn: 0.2395569	total: 3.77s	remaining: 1.63s
# 349:	learn: 0.2395561	total: 3.77s	remaining: 1.62s
# 350:	learn: 0.2395551	total: 3.78s	remaining: 1.61s
# 351:	learn: 0.2395536	total: 3.79s	remaining: 1.59s
# 352:	learn: 0.2395496	total: 3.8s	remaining: 1.58s
# 353:	learn: 0.2395474	total: 3.81s	remaining: 1.57s
# 354:	learn: 0.2395454	total: 3.82s	remaining: 1.56s
# 355:	learn: 0.2395448	total: 3.83s	remaining: 1.55s
# 356:	learn: 0.2395440	total: 3.84s	remaining: 1.54s
# 357:	learn: 0.2395438	total: 3.85s	remaining: 1.53s
# 358:	learn: 0.2395433	total: 3.86s	remaining: 1.51s
# 359:	learn: 0.2395429	total: 3.87s	remaining: 1.5s
# 360:	learn: 0.2395401	total: 3.88s	remaining: 1.49s
# 361:	learn: 0.2395399	total: 3.89s	remaining: 1.48s
# 362:	learn: 0.2395384	total: 3.9s	remaining: 1.47s
# 363:	learn: 0.2395359	total: 3.91s	remaining: 1.46s
# 364:	learn: 0.2395336	total: 3.93s	remaining: 1.45s
# 365:	learn: 0.2395320	total: 3.94s	remaining: 1.44s
# 366:	learn: 0.2395265	total: 3.98s	remaining: 1.44s
# 367:	learn: 0.2395248	total: 3.99s	remaining: 1.43s
# 368:	learn: 0.2395232	total: 4s	remaining: 1.42s
# 369:	learn: 0.2395205	total: 4.01s	remaining: 1.41s
# 370:	learn: 0.2395189	total: 4.02s	remaining: 1.4s
# 371:	learn: 0.2395172	total: 4.03s	remaining: 1.39s
# 372:	learn: 0.2395147	total: 4.04s	remaining: 1.37s
# 373:	learn: 0.2395122	total: 4.05s	remaining: 1.36s
# 374:	learn: 0.2395102	total: 4.06s	remaining: 1.35s
# 375:	learn: 0.2395084	total: 4.07s	remaining: 1.34s
# 376:	learn: 0.2395063	total: 4.08s	remaining: 1.33s
# 377:	learn: 0.2395056	total: 4.09s	remaining: 1.32s
# 378:	learn: 0.2395021	total: 4.1s	remaining: 1.31s
# 379:	learn: 0.2395005	total: 4.11s	remaining: 1.3s
# 380:	learn: 0.2394983	total: 4.12s	remaining: 1.29s
# 381:	learn: 0.2394966	total: 4.13s	remaining: 1.28s
# 382:	learn: 0.2394938	total: 4.14s	remaining: 1.26s
# 383:	learn: 0.2394909	total: 4.15s	remaining: 1.25s
# 384:	learn: 0.2394883	total: 4.16s	remaining: 1.24s
# 385:	learn: 0.2394872	total: 4.17s	remaining: 1.23s
# 386:	learn: 0.2394854	total: 4.18s	remaining: 1.22s
# 387:	learn: 0.2394840	total: 4.19s	remaining: 1.21s
# 388:	learn: 0.2394800	total: 4.2s	remaining: 1.2s
# 389:	learn: 0.2394791	total: 4.21s	remaining: 1.19s
# 390:	learn: 0.2394763	total: 4.22s	remaining: 1.18s
# 391:	learn: 0.2394739	total: 4.23s	remaining: 1.17s
# 392:	learn: 0.2394715	total: 4.25s	remaining: 1.16s
# 393:	learn: 0.2394700	total: 4.26s	remaining: 1.15s
# 394:	learn: 0.2394686	total: 4.27s	remaining: 1.13s
# 395:	learn: 0.2394665	total: 4.28s	remaining: 1.12s
# 396:	learn: 0.2394648	total: 4.29s	remaining: 1.11s
# 397:	learn: 0.2394619	total: 4.3s	remaining: 1.1s
# 398:	learn: 0.2394592	total: 4.31s	remaining: 1.09s
# 399:	learn: 0.2394577	total: 4.32s	remaining: 1.08s
# 400:	learn: 0.2394557	total: 4.33s	remaining: 1.07s
# 401:	learn: 0.2394540	total: 4.35s	remaining: 1.06s
# 402:	learn: 0.2394515	total: 4.37s	remaining: 1.05s
# 403:	learn: 0.2394491	total: 4.38s	remaining: 1.04s
# 404:	learn: 0.2394460	total: 4.39s	remaining: 1.03s
# 405:	learn: 0.2394444	total: 4.4s	remaining: 1.02s
# 406:	learn: 0.2394420	total: 4.41s	remaining: 1.01s
# 407:	learn: 0.2394404	total: 4.42s	remaining: 996ms
# 408:	learn: 0.2394362	total: 4.43s	remaining: 985ms
# 409:	learn: 0.2394335	total: 4.44s	remaining: 974ms
# 410:	learn: 0.2394318	total: 4.45s	remaining: 963ms
# 411:	learn: 0.2394304	total: 4.46s	remaining: 952ms
# 412:	learn: 0.2394265	total: 4.47s	remaining: 941ms
# 413:	learn: 0.2394252	total: 4.48s	remaining: 930ms
# 414:	learn: 0.2394240	total: 4.49s	remaining: 920ms
# 415:	learn: 0.2394229	total: 4.5s	remaining: 909ms
# 416:	learn: 0.2394211	total: 4.51s	remaining: 898ms
# 417:	learn: 0.2394209	total: 4.52s	remaining: 887ms
# 418:	learn: 0.2394184	total: 4.53s	remaining: 876ms
# 419:	learn: 0.2394167	total: 4.54s	remaining: 865ms
# 420:	learn: 0.2394156	total: 4.55s	remaining: 854ms
# 469:	learn: 0.2393202	total: 5.1s	remaining: 326ms
# 470:	learn: 0.2393180	total: 5.11s	remaining: 315ms
# 471:	learn: 0.2393164	total: 5.12s	remaining: 304ms
# 472:	learn: 0.2393139	total: 5.14s	remaining: 293ms
# 473:	learn: 0.2393119	total: 5.15s	remaining: 282ms
# 474:	learn: 0.2393090	total: 5.16s	remaining: 272ms
# 475:	learn: 0.2393032	total: 5.17s	remaining: 261ms
# 476:	learn: 0.2393021	total: 5.18s	remaining: 250ms
# 477:	learn: 0.2393000	total: 5.2s	remaining: 239ms
# 478:	learn: 0.2392972	total: 5.21s	remaining: 228ms
# 479:	learn: 0.2392957	total: 5.21s	remaining: 217ms
# 480:	learn: 0.2392941	total: 5.22s	remaining: 206ms
# 481:	learn: 0.2392920	total: 5.24s	remaining: 196ms
# 482:	learn: 0.2392900	total: 5.25s	remaining: 185ms
# 483:	learn: 0.2392862	total: 5.26s	remaining: 174ms
# 484:	learn: 0.2392828	total: 5.27s	remaining: 163ms
# 485:	learn: 0.2392806	total: 5.28s	remaining: 152ms
# 486:	learn: 0.2392784	total: 5.29s	remaining: 141ms
# 487:	learn: 0.2392770	total: 5.3s	remaining: 130ms
# 488:	learn: 0.2392756	total: 5.31s	remaining: 119ms
# 489:	learn: 0.2392737	total: 5.32s	remaining: 109ms
# 490:	learn: 0.2392703	total: 5.33s	remaining: 97.8ms
# 491:	learn: 0.2392686	total: 5.35s	remaining: 87ms
# 492:	learn: 0.2392672	total: 5.36s	remaining: 76.1ms
# 493:	learn: 0.2392656	total: 5.38s	remaining: 65.3ms
# 494:	learn: 0.2392651	total: 5.38s	remaining: 54.4ms
# 495:	learn: 0.2392632	total: 5.39s	remaining: 43.5ms
# 496:	learn: 0.2392615	total: 5.41s	remaining: 32.6ms
# 497:	learn: 0.2392587	total: 5.42s	remaining: 21.8ms
# 498:	learn: 0.2392576	total: 5.43s	remaining: 10.9ms
# 499:	learn: 0.2392557	total: 5.44s	remaining: 0us
# 0:	learn: 0.2523985	total: 6.26ms	remaining: 3.13s
# 1:	learn: 0.2523870	total: 11.5ms	remaining: 2.86s
# 2:	learn: 0.2523825	total: 16.9ms	remaining: 2.8s
# 3:	learn: 0.2523723	total: 22.7ms	remaining: 2.81s
# 4:	learn: 0.2523613	total: 28.2ms	remaining: 2.79s
# 5:	learn: 0.2523534	total: 33.3ms	remaining: 2.74s
# 6:	learn: 0.2523454	total: 38.5ms	remaining: 2.71s
# 7:	learn: 0.2523362	total: 43.4ms	remaining: 2.67s
# 8:	learn: 0.2523298	total: 48.3ms	remaining: 2.64s
# 9:	learn: 0.2523238	total: 53.9ms	remaining: 2.64s
# 10:	learn: 0.2523196	total: 60.4ms	remaining: 2.69s
# 11:	learn: 0.2523103	total: 66.4ms	remaining: 2.7s
# 12:	learn: 0.2523070	total: 71.5ms	remaining: 2.68s
# 13:	learn: 0.2523003	total: 76.9ms	remaining: 2.67s
# 14:	learn: 0.2522975	total: 82.6ms	remaining: 2.67s
# 15:	learn: 0.2522919	total: 88ms	remaining: 2.66s
# 16:	learn: 0.2522889	total: 93.6ms	remaining: 2.66s
# 17:	learn: 0.2522838	total: 99.4ms	remaining: 2.66s
# 18:	learn: 0.2522802	total: 106ms	remaining: 2.67s
# 19:	learn: 0.2522726	total: 112ms	remaining: 2.68s
# 20:	learn: 0.2522640	total: 118ms	remaining: 2.69s
# 21:	learn: 0.2522574	total: 125ms	remaining: 2.71s
# 22:	learn: 0.2522480	total: 131ms	remaining: 2.72s
# 23:	learn: 0.2522433	total: 137ms	remaining: 2.72s
# 24:	learn: 0.2522374	total: 142ms	remaining: 2.71s
# 25:	learn: 0.2522302	total: 148ms	remaining: 2.69s
# 26:	learn: 0.2522247	total: 153ms	remaining: 2.68s
# 27:	learn: 0.2522207	total: 158ms	remaining: 2.66s
# 28:	learn: 0.2522161	total: 163ms	remaining: 2.64s
# 29:	learn: 0.2522082	total: 168ms	remaining: 2.63s
# 30:	learn: 0.2522013	total: 173ms	remaining: 2.62s
# 31:	learn: 0.2521951	total: 178ms	remaining: 2.6s
# 32:	learn: 0.2521891	total: 184ms	remaining: 2.6s
# 33:	learn: 0.2521808	total: 189ms	remaining: 2.59s
# 34:	learn: 0.2521764	total: 194ms	remaining: 2.58s
# 35:	learn: 0.2521700	total: 199ms	remaining: 2.57s
# 36:	learn: 0.2521607	total: 204ms	remaining: 2.56s
# 37:	learn: 0.2521571	total: 210ms	remaining: 2.55s
# 38:	learn: 0.2521504	total: 215ms	remaining: 2.54s
# 39:	learn: 0.2521428	total: 220ms	remaining: 2.53s
# 40:	learn: 0.2521386	total: 225ms	remaining: 2.52s
# 41:	learn: 0.2521342	total: 230ms	remaining: 2.51s
# 42:	learn: 0.2521315	total: 235ms	remaining: 2.5s
# 43:	learn: 0.2521252	total: 241ms	remaining: 2.5s
# 44:	learn: 0.2521202	total: 246ms	remaining: 2.49s
# 45:	learn: 0.2521139	total: 252ms	remaining: 2.48s
# 46:	learn: 0.2521109	total: 257ms	remaining: 2.47s
# 47:	learn: 0.2521068	total: 262ms	remaining: 2.47s
# 48:	learn: 0.2521037	total: 267ms	remaining: 2.46s
# 49:	learn: 0.2521003	total: 272ms	remaining: 2.45s
# 50:	learn: 0.2520964	total: 277ms	remaining: 2.44s
# 51:	learn: 0.2520926	total: 283ms	remaining: 2.44s
# 52:	learn: 0.2520866	total: 288ms	remaining: 2.43s
# 53:	learn: 0.2520833	total: 294ms	remaining: 2.43s
# 54:	learn: 0.2520778	total: 300ms	remaining: 2.43s
# 55:	learn: 0.2520757	total: 306ms	remaining: 2.42s
# 56:	learn: 0.2520715	total: 312ms	remaining: 2.42s
# 57:	learn: 0.2520664	total: 319ms	remaining: 2.43s
# 58:	learn: 0.2520614	total: 325ms	remaining: 2.43s
# 59:	learn: 0.2520581	total: 331ms	remaining: 2.43s
# 60:	learn: 0.2520515	total: 338ms	remaining: 2.43s
# 61:	learn: 0.2520453	total: 345ms	remaining: 2.43s
# 62:	learn: 0.2520417	total: 351ms	remaining: 2.43s
# 63:	learn: 0.2520359	total: 357ms	remaining: 2.43s
# 64:	learn: 0.2520330	total: 362ms	remaining: 2.42s
# 65:	learn: 0.2520268	total: 367ms	remaining: 2.41s
# 66:	learn: 0.2520208	total: 372ms	remaining: 2.4s
# 67:	learn: 0.2520162	total: 377ms	remaining: 2.39s
# 68:	learn: 0.2520103	total: 382ms	remaining: 2.39s
# 69:	learn: 0.2520076	total: 387ms	remaining: 2.38s
# 70:	learn: 0.2520002	total: 393ms	remaining: 2.37s
# 71:	learn: 0.2519971	total: 398ms	remaining: 2.37s
# 72:	learn: 0.2519918	total: 404ms	remaining: 2.36s
# 73:	learn: 0.2519876	total: 409ms	remaining: 2.35s
# 74:	learn: 0.2519791	total: 415ms	remaining: 2.35s
# 75:	learn: 0.2519732	total: 420ms	remaining: 2.34s
# 76:	learn: 0.2519665	total: 426ms	remaining: 2.34s
# 77:	learn: 0.2519631	total: 431ms	remaining: 2.33s
# 78:	learn: 0.2519546	total: 436ms	remaining: 2.32s
# 79:	learn: 0.2519506	total: 441ms	remaining: 2.31s
# 80:	learn: 0.2519448	total: 446ms	remaining: 2.31s
# 81:	learn: 0.2519366	total: 451ms	remaining: 2.3s
# 82:	learn: 0.2519339	total: 456ms	remaining: 2.29s
# 83:	learn: 0.2519291	total: 462ms	remaining: 2.29s
# 84:	learn: 0.2519255	total: 467ms	remaining: 2.28s
# 85:	learn: 0.2519209	total: 472ms	remaining: 2.27s
# 86:	learn: 0.2519183	total: 477ms	remaining: 2.26s
# 87:	learn: 0.2519163	total: 482ms	remaining: 2.26s
# 88:	learn: 0.2519102	total: 488ms	remaining: 2.25s
# 89:	learn: 0.2519064	total: 494ms	remaining: 2.25s
# 90:	learn: 0.2518975	total: 500ms	remaining: 2.25s
# 91:	learn: 0.2518931	total: 506ms	remaining: 2.25s
# 92:	learn: 0.2518893	total: 514ms	remaining: 2.25s
# 93:	learn: 0.2518877	total: 520ms	remaining: 2.24s
# 94:	learn: 0.2518826	total: 526ms	remaining: 2.24s
# 95:	learn: 0.2518787	total: 534ms	remaining: 2.25s
# 96:	learn: 0.2518737	total: 540ms	remaining: 2.24s
# 97:	learn: 0.2518706	total: 549ms	remaining: 2.25s
# 98:	learn: 0.2518676	total: 558ms	remaining: 2.26s
# 99:	learn: 0.2518624	total: 565ms	remaining: 2.26s
# 100:	learn: 0.2518567	total: 571ms	remaining: 2.26s
# 101:	learn: 0.2518469	total: 580ms	remaining: 2.26s
# 102:	learn: 0.2518407	total: 588ms	remaining: 2.27s
# 103:	learn: 0.2518346	total: 596ms	remaining: 2.27s
# 104:	learn: 0.2518285	total: 602ms	remaining: 2.26s
# 105:	learn: 0.2518204	total: 609ms	remaining: 2.26s
# 106:	learn: 0.2518170	total: 615ms	remaining: 2.26s
# 107:	learn: 0.2518121	total: 620ms	remaining: 2.25s
# 108:	learn: 0.2518086	total: 627ms	remaining: 2.25s
# 109:	learn: 0.2518024	total: 633ms	remaining: 2.24s
# 110:	learn: 0.2517987	total: 638ms	remaining: 2.24s
# 159:	learn: 0.2515380	total: 918ms	remaining: 1.95s
# 160:	learn: 0.2515359	total: 923ms	remaining: 1.94s
# 161:	learn: 0.2515266	total: 928ms	remaining: 1.94s
# 162:	learn: 0.2515180	total: 934ms	remaining: 1.93s
# 163:	learn: 0.2515132	total: 939ms	remaining: 1.92s
# 164:	learn: 0.2515060	total: 945ms	remaining: 1.92s
# 165:	learn: 0.2515020	total: 950ms	remaining: 1.91s
# 166:	learn: 0.2514884	total: 955ms	remaining: 1.91s
# 167:	learn: 0.2514863	total: 961ms	remaining: 1.9s
# 168:	learn: 0.2514811	total: 966ms	remaining: 1.89s
# 169:	learn: 0.2514758	total: 971ms	remaining: 1.88s
# 170:	learn: 0.2514724	total: 976ms	remaining: 1.88s
# 171:	learn: 0.2514666	total: 982ms	remaining: 1.87s
# 172:	learn: 0.2514637	total: 988ms	remaining: 1.87s
# 173:	learn: 0.2514587	total: 994ms	remaining: 1.86s
# 174:	learn: 0.2514527	total: 1000ms	remaining: 1.86s
# 175:	learn: 0.2514475	total: 1.01s	remaining: 1.85s
# 176:	learn: 0.2514431	total: 1.01s	remaining: 1.85s
# 177:	learn: 0.2514382	total: 1.02s	remaining: 1.84s
# 178:	learn: 0.2514365	total: 1.02s	remaining: 1.84s
# 179:	learn: 0.2514259	total: 1.03s	remaining: 1.83s
# 180:	learn: 0.2514210	total: 1.04s	remaining: 1.83s
# 181:	learn: 0.2514136	total: 1.04s	remaining: 1.82s
# 182:	learn: 0.2514063	total: 1.05s	remaining: 1.82s
# 183:	learn: 0.2514000	total: 1.06s	remaining: 1.81s
# 184:	learn: 0.2513935	total: 1.06s	remaining: 1.81s
# 185:	learn: 0.2513888	total: 1.07s	remaining: 1.8s
# 186:	learn: 0.2513866	total: 1.07s	remaining: 1.8s
# 187:	learn: 0.2513825	total: 1.08s	remaining: 1.79s
# 188:	learn: 0.2513807	total: 1.08s	remaining: 1.78s
# 189:	learn: 0.2513699	total: 1.09s	remaining: 1.78s
# 190:	learn: 0.2513618	total: 1.1s	remaining: 1.77s
# 191:	learn: 0.2513546	total: 1.1s	remaining: 1.77s
# 192:	learn: 0.2513478	total: 1.11s	remaining: 1.76s
# 193:	learn: 0.2513420	total: 1.11s	remaining: 1.76s
# 194:	learn: 0.2513347	total: 1.12s	remaining: 1.75s
# 195:	learn: 0.2513316	total: 1.13s	remaining: 1.75s
# 196:	learn: 0.2513232	total: 1.13s	remaining: 1.74s
# 197:	learn: 0.2513171	total: 1.14s	remaining: 1.74s
# 198:	learn: 0.2513072	total: 1.15s	remaining: 1.73s
# 199:	learn: 0.2513038	total: 1.15s	remaining: 1.73s
# 200:	learn: 0.2512956	total: 1.16s	remaining: 1.72s
# 201:	learn: 0.2512912	total: 1.16s	remaining: 1.71s
# 202:	learn: 0.2512895	total: 1.17s	remaining: 1.71s
# 203:	learn: 0.2512840	total: 1.17s	remaining: 1.7s
# 204:	learn: 0.2512814	total: 1.18s	remaining: 1.69s
# 205:	learn: 0.2512793	total: 1.18s	remaining: 1.69s
# 206:	learn: 0.2512772	total: 1.19s	remaining: 1.68s
# 207:	learn: 0.2512727	total: 1.19s	remaining: 1.67s
# 208:	learn: 0.2512679	total: 1.2s	remaining: 1.67s
# 209:	learn: 0.2512606	total: 1.2s	remaining: 1.66s
# 210:	learn: 0.2512539	total: 1.21s	remaining: 1.65s
# 211:	learn: 0.2512472	total: 1.21s	remaining: 1.65s
# 212:	learn: 0.2512405	total: 1.22s	remaining: 1.64s
# 213:	learn: 0.2512387	total: 1.22s	remaining: 1.64s
# 214:	learn: 0.2512335	total: 1.23s	remaining: 1.63s
# 215:	learn: 0.2512287	total: 1.24s	remaining: 1.63s
# 216:	learn: 0.2512231	total: 1.24s	remaining: 1.62s
# 217:	learn: 0.2512198	total: 1.25s	remaining: 1.61s
# 218:	learn: 0.2512143	total: 1.25s	remaining: 1.61s
# 219:	learn: 0.2512087	total: 1.26s	remaining: 1.6s
# 220:	learn: 0.2511999	total: 1.27s	remaining: 1.6s
# 221:	learn: 0.2511984	total: 1.27s	remaining: 1.59s
# 222:	learn: 0.2511945	total: 1.28s	remaining: 1.59s
# 223:	learn: 0.2511870	total: 1.28s	remaining: 1.58s
# 224:	learn: 0.2511817	total: 1.29s	remaining: 1.58s
# 225:	learn: 0.2511799	total: 1.3s	remaining: 1.57s
# 226:	learn: 0.2511713	total: 1.31s	remaining: 1.57s
# 227:	learn: 0.2511660	total: 1.31s	remaining: 1.57s
# 228:	learn: 0.2511643	total: 1.32s	remaining: 1.56s
# 229:	learn: 0.2511590	total: 1.32s	remaining: 1.55s
# 230:	learn: 0.2511576	total: 1.33s	remaining: 1.55s
# 231:	learn: 0.2511510	total: 1.33s	remaining: 1.54s
# 232:	learn: 0.2511480	total: 1.34s	remaining: 1.53s
# 233:	learn: 0.2511447	total: 1.34s	remaining: 1.53s
# 234:	learn: 0.2511381	total: 1.35s	remaining: 1.52s
# 235:	learn: 0.2511288	total: 1.36s	remaining: 1.52s
# 236:	learn: 0.2511247	total: 1.36s	remaining: 1.51s
# 237:	learn: 0.2511222	total: 1.37s	remaining: 1.5s
# 238:	learn: 0.2511150	total: 1.37s	remaining: 1.5s
# 239:	learn: 0.2511072	total: 1.38s	remaining: 1.49s
# 240:	learn: 0.2511012	total: 1.38s	remaining: 1.49s
# 241:	learn: 0.2510953	total: 1.39s	remaining: 1.48s
# 242:	learn: 0.2510907	total: 1.39s	remaining: 1.48s
# 243:	learn: 0.2510884	total: 1.4s	remaining: 1.47s
# 244:	learn: 0.2510790	total: 1.41s	remaining: 1.46s
# 245:	learn: 0.2510738	total: 1.41s	remaining: 1.46s
# 246:	learn: 0.2510598	total: 1.42s	remaining: 1.45s
# 247:	learn: 0.2510545	total: 1.42s	remaining: 1.45s
# 248:	learn: 0.2510526	total: 1.43s	remaining: 1.44s
# 249:	learn: 0.2510508	total: 1.43s	remaining: 1.43s
# 250:	learn: 0.2510481	total: 1.44s	remaining: 1.43s
# 251:	learn: 0.2510414	total: 1.44s	remaining: 1.42s
# 252:	learn: 0.2510345	total: 1.45s	remaining: 1.41s
# 253:	learn: 0.2510318	total: 1.45s	remaining: 1.41s
# 254:	learn: 0.2510237	total: 1.46s	remaining: 1.4s
# 255:	learn: 0.2510157	total: 1.46s	remaining: 1.39s
# 256:	learn: 0.2510095	total: 1.47s	remaining: 1.39s
# 257:	learn: 0.2510055	total: 1.47s	remaining: 1.38s
# 258:	learn: 0.2509997	total: 1.48s	remaining: 1.38s
# 259:	learn: 0.2509978	total: 1.49s	remaining: 1.37s
# 260:	learn: 0.2509938	total: 1.49s	remaining: 1.37s
# 261:	learn: 0.2509882	total: 1.5s	remaining: 1.36s
# 262:	learn: 0.2509827	total: 1.5s	remaining: 1.36s
# 263:	learn: 0.2509777	total: 1.51s	remaining: 1.35s
# 264:	learn: 0.2509717	total: 1.52s	remaining: 1.35s
# 265:	learn: 0.2509653	total: 1.53s	remaining: 1.35s
# 266:	learn: 0.2509567	total: 1.54s	remaining: 1.34s
# 267:	learn: 0.2509494	total: 1.55s	remaining: 1.34s
# 268:	learn: 0.2509472	total: 1.55s	remaining: 1.33s
# 269:	learn: 0.2509418	total: 1.56s	remaining: 1.33s
# 270:	learn: 0.2509314	total: 1.56s	remaining: 1.32s
# 271:	learn: 0.2509249	total: 1.57s	remaining: 1.31s
# 272:	learn: 0.2509177	total: 1.57s	remaining: 1.31s
# 273:	learn: 0.2509141	total: 1.58s	remaining: 1.3s
# 274:	learn: 0.2509090	total: 1.58s	remaining: 1.3s
# 275:	learn: 0.2509002	total: 1.59s	remaining: 1.29s
# 276:	learn: 0.2508984	total: 1.59s	remaining: 1.28s
# 277:	learn: 0.2508938	total: 1.6s	remaining: 1.28s
# 278:	learn: 0.2508905	total: 1.6s	remaining: 1.27s
# 279:	learn: 0.2508853	total: 1.61s	remaining: 1.26s
# 280:	learn: 0.2508803	total: 1.62s	remaining: 1.26s
# 281:	learn: 0.2508777	total: 1.62s	remaining: 1.25s
# 282:	learn: 0.2508763	total: 1.63s	remaining: 1.25s
# 283:	learn: 0.2508742	total: 1.63s	remaining: 1.24s
# 284:	learn: 0.2508675	total: 1.64s	remaining: 1.23s
# 285:	learn: 0.2508633	total: 1.64s	remaining: 1.23s
# 286:	learn: 0.2508571	total: 1.65s	remaining: 1.22s
# 287:	learn: 0.2508536	total: 1.65s	remaining: 1.22s
# 288:	learn: 0.2508478	total: 1.66s	remaining: 1.21s
# 289:	learn: 0.2508440	total: 1.66s	remaining: 1.2s
# 290:	learn: 0.2508373	total: 1.67s	remaining: 1.2s
# 291:	learn: 0.2508311	total: 1.67s	remaining: 1.19s
# 292:	learn: 0.2508278	total: 1.68s	remaining: 1.19s
# 293:	learn: 0.2508254	total: 1.68s	remaining: 1.18s
# 294:	learn: 0.2508234	total: 1.69s	remaining: 1.17s
# 295:	learn: 0.2508193	total: 1.69s	remaining: 1.17s
# 296:	learn: 0.2508121	total: 1.7s	remaining: 1.16s
# 297:	learn: 0.2508050	total: 1.71s	remaining: 1.16s
# 298:	learn: 0.2507990	total: 1.71s	remaining: 1.15s
# 299:	learn: 0.2507908	total: 1.72s	remaining: 1.15s
# 300:	learn: 0.2507797	total: 1.73s	remaining: 1.14s
# 301:	learn: 0.2507760	total: 1.73s	remaining: 1.14s
# 302:	learn: 0.2507715	total: 1.74s	remaining: 1.13s
# 303:	learn: 0.2507645	total: 1.74s	remaining: 1.12s
# 304:	learn: 0.2507582	total: 1.75s	remaining: 1.12s
# 305:	learn: 0.2507540	total: 1.75s	remaining: 1.11s
# 306:	learn: 0.2507503	total: 1.76s	remaining: 1.11s
# 307:	learn: 0.2507482	total: 1.77s	remaining: 1.1s
# 308:	learn: 0.2507441	total: 1.77s	remaining: 1.09s
# 309:	learn: 0.2507405	total: 1.78s	remaining: 1.09s
# 310:	learn: 0.2507326	total: 1.78s	remaining: 1.08s
# 311:	learn: 0.2507262	total: 1.79s	remaining: 1.08s
# 312:	learn: 0.2507231	total: 1.79s	remaining: 1.07s
# 313:	learn: 0.2507176	total: 1.8s	remaining: 1.07s
# 314:	learn: 0.2507124	total: 1.81s	remaining: 1.06s
# 315:	learn: 0.2507103	total: 1.81s	remaining: 1.06s
# 316:	learn: 0.2507067	total: 1.82s	remaining: 1.05s
# 317:	learn: 0.2507016	total: 1.82s	remaining: 1.04s
# 318:	learn: 0.2506946	total: 1.83s	remaining: 1.04s
# 319:	learn: 0.2506900	total: 1.84s	remaining: 1.03s
# 320:	learn: 0.2506858	total: 1.84s	remaining: 1.03s
# 321:	learn: 0.2506797	total: 1.85s	remaining: 1.02s
# 322:	learn: 0.2506747	total: 1.85s	remaining: 1.01s
# 323:	learn: 0.2506693	total: 1.86s	remaining: 1.01s
# 324:	learn: 0.2506635	total: 1.86s	remaining: 1s
# 325:	learn: 0.2506594	total: 1.87s	remaining: 997ms
# 326:	learn: 0.2506548	total: 1.87s	remaining: 992ms
# 327:	learn: 0.2506481	total: 1.88s	remaining: 986ms
# 328:	learn: 0.2506424	total: 1.89s	remaining: 980ms
# 329:	learn: 0.2506389	total: 1.89s	remaining: 974ms
# 330:	learn: 0.2506355	total: 1.9s	remaining: 969ms
# 331:	learn: 0.2506306	total: 1.9s	remaining: 963ms
# 332:	learn: 0.2506251	total: 1.91s	remaining: 957ms
# 333:	learn: 0.2506224	total: 1.92s	remaining: 952ms
# 334:	learn: 0.2506182	total: 1.92s	remaining: 947ms
# 335:	learn: 0.2506140	total: 1.93s	remaining: 941ms
# 336:	learn: 0.2506047	total: 1.93s	remaining: 935ms
# 337:	learn: 0.2506012	total: 1.94s	remaining: 929ms
# 338:	learn: 0.2505973	total: 1.94s	remaining: 923ms
# 339:	learn: 0.2505929	total: 1.95s	remaining: 917ms
# 340:	learn: 0.2505882	total: 1.95s	remaining: 911ms
# 341:	learn: 0.2505862	total: 1.96s	remaining: 905ms
# 342:	learn: 0.2505784	total: 1.96s	remaining: 899ms
# 343:	learn: 0.2505760	total: 1.97s	remaining: 893ms
# 344:	learn: 0.2505733	total: 1.97s	remaining: 887ms
# 345:	learn: 0.2505678	total: 1.98s	remaining: 881ms
# 346:	learn: 0.2505641	total: 1.99s	remaining: 876ms
# 347:	learn: 0.2505574	total: 1.99s	remaining: 870ms
# 348:	learn: 0.2505525	total: 2s	remaining: 864ms
# 349:	learn: 0.2505490	total: 2s	remaining: 859ms
# 350:	learn: 0.2505428	total: 2.01s	remaining: 853ms
# 351:	learn: 0.2505358	total: 2.02s	remaining: 848ms
# 352:	learn: 0.2505323	total: 2.02s	remaining: 843ms
# 353:	learn: 0.2505239	total: 2.03s	remaining: 837ms
# 354:	learn: 0.2505193	total: 2.04s	remaining: 832ms
# 355:	learn: 0.2505144	total: 2.04s	remaining: 826ms
# 356:	learn: 0.2505089	total: 2.05s	remaining: 820ms
# 357:	learn: 0.2505058	total: 2.05s	remaining: 815ms
# 358:	learn: 0.2505011	total: 2.06s	remaining: 809ms
# 359:	learn: 0.2504957	total: 2.06s	remaining: 803ms
# 360:	learn: 0.2504925	total: 2.07s	remaining: 798ms
# 361:	learn: 0.2504863	total: 2.08s	remaining: 792ms
# 362:	learn: 0.2504828	total: 2.08s	remaining: 786ms
# 363:	learn: 0.2504813	total: 2.09s	remaining: 781ms
# 364:	learn: 0.2504771	total: 2.09s	remaining: 775ms
# 365:	learn: 0.2504724	total: 2.1s	remaining: 770ms
# 366:	learn: 0.2504690	total: 2.11s	remaining: 764ms
# 367:	learn: 0.2504660	total: 2.11s	remaining: 758ms
# 368:	learn: 0.2504632	total: 2.12s	remaining: 753ms
# 369:	learn: 0.2504577	total: 2.13s	remaining: 748ms
# 370:	learn: 0.2504519	total: 2.13s	remaining: 742ms
# 371:	learn: 0.2504465	total: 2.14s	remaining: 736ms
# 372:	learn: 0.2504399	total: 2.14s	remaining: 730ms
# 373:	learn: 0.2504337	total: 2.15s	remaining: 724ms
# 374:	learn: 0.2504268	total: 2.15s	remaining: 718ms
# 375:	learn: 0.2504227	total: 2.16s	remaining: 712ms
# 376:	learn: 0.2504183	total: 2.17s	remaining: 706ms
# 377:	learn: 0.2504137	total: 2.17s	remaining: 701ms
# 378:	learn: 0.2504095	total: 2.17s	remaining: 695ms
# 379:	learn: 0.2504026	total: 2.18s	remaining: 689ms
# 380:	learn: 0.2503964	total: 2.19s	remaining: 683ms
# 381:	learn: 0.2503867	total: 2.19s	remaining: 677ms
# 382:	learn: 0.2503839	total: 2.2s	remaining: 671ms
# 383:	learn: 0.2503790	total: 2.2s	remaining: 665ms
# 384:	learn: 0.2503747	total: 2.21s	remaining: 660ms
# 385:	learn: 0.2503691	total: 2.21s	remaining: 654ms
# 386:	learn: 0.2503624	total: 2.22s	remaining: 648ms
# 387:	learn: 0.2503489	total: 2.22s	remaining: 642ms
# 388:	learn: 0.2503445	total: 2.23s	remaining: 636ms
# 389:	learn: 0.2503361	total: 2.23s	remaining: 630ms
# 390:	learn: 0.2503284	total: 2.24s	remaining: 625ms
# 391:	learn: 0.2503258	total: 2.25s	remaining: 619ms
# 392:	learn: 0.2503198	total: 2.25s	remaining: 613ms
# 393:	learn: 0.2503176	total: 2.26s	remaining: 607ms
# 394:	learn: 0.2503107	total: 2.26s	remaining: 602ms
# 395:	learn: 0.2503077	total: 2.27s	remaining: 596ms
# 396:	learn: 0.2503031	total: 2.27s	remaining: 590ms
# 397:	learn: 0.2502994	total: 2.28s	remaining: 585ms
# 398:	learn: 0.2502951	total: 2.29s	remaining: 579ms
# 399:	learn: 0.2502906	total: 2.29s	remaining: 573ms
# 400:	learn: 0.2502868	total: 2.31s	remaining: 570ms
# 401:	learn: 0.2502812	total: 2.31s	remaining: 564ms
# 402:	learn: 0.2502735	total: 2.32s	remaining: 559ms
# 403:	learn: 0.2502654	total: 2.33s	remaining: 554ms
# 404:	learn: 0.2502602	total: 2.34s	remaining: 548ms
# 405:	learn: 0.2502547	total: 2.34s	remaining: 542ms
# 406:	learn: 0.2502481	total: 2.35s	remaining: 537ms
# 407:	learn: 0.2502423	total: 2.35s	remaining: 531ms
# 408:	learn: 0.2502388	total: 2.36s	remaining: 525ms
# 409:	learn: 0.2502323	total: 2.37s	remaining: 520ms
# 410:	learn: 0.2502274	total: 2.37s	remaining: 514ms
# 411:	learn: 0.2502223	total: 2.38s	remaining: 508ms
# 412:	learn: 0.2502170	total: 2.38s	remaining: 502ms
# 413:	learn: 0.2502108	total: 2.39s	remaining: 496ms
# 414:	learn: 0.2502043	total: 2.39s	remaining: 490ms
# 415:	learn: 0.2501994	total: 2.4s	remaining: 485ms
# 416:	learn: 0.2501928	total: 2.4s	remaining: 479ms
# 417:	learn: 0.2501897	total: 2.41s	remaining: 473ms
# 418:	learn: 0.2501848	total: 2.42s	remaining: 467ms
# 419:	learn: 0.2501835	total: 2.42s	remaining: 461ms
# 420:	learn: 0.2501794	total: 2.43s	remaining: 455ms
# 421:	learn: 0.2501756	total: 2.43s	remaining: 449ms
# 422:	learn: 0.2501708	total: 2.44s	remaining: 443ms
# 423:	learn: 0.2501633	total: 2.44s	remaining: 438ms
# 424:	learn: 0.2501617	total: 2.45s	remaining: 432ms
# 425:	learn: 0.2501590	total: 2.45s	remaining: 426ms
# 426:	learn: 0.2501519	total: 2.46s	remaining: 420ms
# 427:	learn: 0.2501479	total: 2.46s	remaining: 414ms
# 428:	learn: 0.2501475	total: 2.47s	remaining: 408ms
# ...
# 194:	learn: 0.2389218	total: 357ms	remaining: 559ms
# 195:	learn: 0.2388867	total: 361ms	remaining: 560ms
# 196:	learn: 0.2388403	total: 363ms	remaining: 559ms
# 197:	learn: 0.2388065	total: 366ms	remaining: 558ms
# 198:	learn: 0.2387908	total: 368ms	remaining: 556ms
# 199:	learn: 0.2387144	total: 370ms	remaining: 556ms
# 200:	learn: 0.2386597	total: 373ms	remaining: 554ms
# 201:	learn: 0.2385869	total: 375ms	remaining: 553ms
# 202:	learn: 0.2385245	total: 377ms	remaining: 552ms
# 203:	learn: 0.2384737	total: 379ms	remaining: 550ms
# 204:	learn: 0.2384047	total: 381ms	remaining: 548ms
# 205:	learn: 0.2383718	total: 382ms	remaining: 546ms
# 206:	learn: 0.2383054	total: 384ms	remaining: 544ms
# 453:	learn: 0.2290338	total: 797ms	remaining: 80.7ms
# 454:	learn: 0.2290050	total: 798ms	remaining: 78.9ms
# 455:	learn: 0.2289866	total: 800ms	remaining: 77.2ms
# 456:	learn: 0.2289725	total: 801ms	remaining: 75.4ms
# 457:	learn: 0.2289610	total: 802ms	remaining: 73.6ms
# 458:	learn: 0.2289176	total: 804ms	remaining: 71.8ms
# 459:	learn: 0.2288459	total: 805ms	remaining: 70ms
# 460:	learn: 0.2287786	total: 807ms	remaining: 68.2ms
# 461:	learn: 0.2287117	total: 808ms	remaining: 66.5ms
# 462:	learn: 0.2287108	total: 809ms	remaining: 64.7ms
# 463:	learn: 0.2286691	total: 811ms	remaining: 62.9ms
# 464:	learn: 0.2286058	total: 812ms	remaining: 61.1ms
# 465:	learn: 0.2285939	total: 814ms	remaining: 59.4ms
# 466:	learn: 0.2285396	total: 816ms	remaining: 57.6ms
# 467:	learn: 0.2285075	total: 817ms	remaining: 55.9ms
# 468:	learn: 0.2284728	total: 819ms	remaining: 54.1ms
# 469:	learn: 0.2284408	total: 820ms	remaining: 52.3ms
# 470:	learn: 0.2284123	total: 821ms	remaining: 50.6ms
# 471:	learn: 0.2283809	total: 822ms	remaining: 48.8ms
# 472:	learn: 0.2283407	total: 824ms	remaining: 47ms
# 473:	learn: 0.2282757	total: 825ms	remaining: 45.3ms
# 474:	learn: 0.2282341	total: 827ms	remaining: 43.5ms
# 475:	learn: 0.2282044	total: 828ms	remaining: 41.7ms
# 476:	learn: 0.2281672	total: 830ms	remaining: 40ms
# 477:	learn: 0.2281510	total: 831ms	remaining: 38.3ms
# 478:	learn: 0.2281063	total: 835ms	remaining: 36.6ms
# 479:	learn: 0.2280718	total: 840ms	remaining: 35ms
# 480:	learn: 0.2280331	total: 841ms	remaining: 33.2ms
# 481:	learn: 0.2279761	total: 843ms	remaining: 31.5ms
# 482:	learn: 0.2279599	total: 845ms	remaining: 29.8ms
# 483:	learn: 0.2279208	total: 847ms	remaining: 28ms
# 484:	learn: 0.2278984	total: 849ms	remaining: 26.3ms
# 485:	learn: 0.2278824	total: 852ms	remaining: 24.5ms
# 486:	learn: 0.2278368	total: 854ms	remaining: 22.8ms
# 487:	learn: 0.2278233	total: 856ms	remaining: 21.1ms
# 488:	learn: 0.2277667	total: 859ms	remaining: 19.3ms
# 489:	learn: 0.2277265	total: 862ms	remaining: 17.6ms
# 490:	learn: 0.2276955	total: 863ms	remaining: 15.8ms
# 491:	learn: 0.2276463	total: 865ms	remaining: 14.1ms
# 492:	learn: 0.2275876	total: 866ms	remaining: 12.3ms
# 493:	learn: 0.2275615	total: 868ms	remaining: 10.5ms
# 494:	learn: 0.2275235	total: 870ms	remaining: 8.78ms
# 495:	learn: 0.2274807	total: 871ms	remaining: 7.03ms
# 496:	learn: 0.2274327	total: 873ms	remaining: 5.27ms
# 497:	learn: 0.2274033	total: 875ms	remaining: 3.51ms
# 498:	learn: 0.2273502	total: 876ms	remaining: 1.75ms
# 499:	learn: 0.2273255	total: 878ms	remaining: 0us

# %%
#Predictions
fastball_23['pred'] = fastball_model.predict(fastball_23[fastball_features])

sinker_23['pred'] = sinker_model.predict(sinker_23[non_fastball_features])

cutter_23['pred'] = cutter_model.predict(cutter_23[non_fastball_features])

slider_23['pred'] = slider_model.predict(slider_23[non_fastball_features])

sweeper_23['pred'] = sweeper_model.predict(sweeper_23[non_fastball_features])

curveball_23['pred'] = curveball_model.predict(curveball_23[non_fastball_features])

changeup_23['pred'] = changeup_model.predict(changeup_23[non_fastball_features])

splitter_23['pred'] = splitter_model.predict(splitter_23[non_fastball_features])
# Out:
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/668035254.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fastball_23['pred'] = fastball_model.predict(fastball_23[fastball_features])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/668035254.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sinker_23['pred'] = sinker_model.predict(sinker_23[non_fastball_features])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/668035254.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cutter_23['pred'] = cutter_model.predict(cutter_23[non_fastball_features])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/668035254.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slider_23['pred'] = slider_model.predict(slider_23[non_fastball_features])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/668035254.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sweeper_23['pred'] = sweeper_model.predict(sweeper_23[non_fastball_features])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/668035254.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curveball_23['pred'] = curveball_model.predict(curveball_23[non_fastball_features])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/668035254.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   changeup_23['pred'] = changeup_model.predict(changeup_23[non_fastball_features])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/668035254.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   splitter_23['pred'] = splitter_model.predict(splitter_23[non_fastball_features])

# %%
def scale_and_score(df):
    df['scaled'] = df['pred'] - df['pred'].max()
    df['scaled'] = abs(df['scaled'])
    df['scaled'] = df['scaled'] - df['scaled'].mean()
    df['scaled'] = df['scaled'] / df['scaled'].std()
    df['score'] = df['scaled'] * 10 + 100
    return df

scale_and_score(fastball_23)
scale_and_score(sinker_23)
scale_and_score(cutter_23)
scale_and_score(slider_23)
scale_and_score(sweeper_23)
scale_and_score(curveball_23)
scale_and_score(changeup_23)
scale_and_score(splitter_23)

def calculate_mean_scores(df):
    mean_scores = df.groupby('player_name')['score'].mean().reset_index()
    mean_scores.rename(columns={'score': 'mean_scores'}, inplace=True)
    mean_scores = mean_scores.sort_values(by='mean_scores', ascending=False)
    mean_scores['mean_scores'] = mean_scores['mean_scores'].round(2)
    return mean_scores

mean_scores_fastball = calculate_mean_scores(fastball_23)
mean_scores_sinker = calculate_mean_scores(sinker_23)
mean_scores_cutter = calculate_mean_scores(cutter_23)
mean_scores_slider = calculate_mean_scores(slider_23)
mean_scores_sweeper = calculate_mean_scores(sweeper_23)
mean_scores_curveball = calculate_mean_scores(curveball_23)
mean_scores_changeup = calculate_mean_scores(changeup_23)
mean_scores_splitter = calculate_mean_scores(splitter_23)

combined_scores = mean_scores_fastball
combined_scores = combined_scores.merge(mean_scores_sinker, how = 'left', on = 'player_name', suffixes=('','_sinker'))
combined_scores = combined_scores.merge(mean_scores_cutter, how = 'left', on = 'player_name', suffixes=('','_cutter'))
combined_scores = combined_scores.merge(mean_scores_slider, how = 'left', on = 'player_name', suffixes=('','_slider'))
combined_scores = combined_scores.merge(mean_scores_sweeper, how = 'left', on = 'player_name', suffixes=('','_sweeper'))
combined_scores = combined_scores.merge(mean_scores_curveball, how = 'left', on = 'player_name', suffixes=('','_curveball'))
combined_scores = combined_scores.merge(mean_scores_changeup, how = 'left', on = 'player_name', suffixes=('','_changeup'))
combined_scores = combined_scores.merge(mean_scores_splitter, how = 'left', on = 'player_name', suffixes=('','_splitter'))



combined_scores = combined_scores.rename(columns = {
    'mean_scores': 'fastball',
    'mean_scores_sinker': 'sinker',
    'mean_scores_cutter': 'cutter',
    'mean_scores_slider': 'slider',
    'mean_scores_sweeper': 'sweeper',
    'mean_scores_curveball': 'curveball',
    'mean_scores_changeup': 'changeup',
    'mean_scores_splitter': 'splitter'
    }
)

pitch_counts = data_today.groupby(['player_name', 'pitch_type']).size().unstack(fill_value=0).reset_index()

combined_data = combined_scores.merge(pitch_counts, how='left', on='player_name')
combined_data.fillna(0, inplace=True)

combined_data['weighted_fastball'] = combined_data['fastball'] * combined_data['Fastball']
combined_data['weighted_sinker'] = combined_data['sinker'] * combined_data['Sinker']
combined_data['weighted_cutter'] = combined_data['cutter'] * combined_data['Cutter']
combined_data['weighted_slider'] = combined_data['slider'] * combined_data['Slider']
combined_data['weighted_sweeper'] = combined_data['sweeper'] * combined_data['Sweeper']
combined_data['weighted_curveball'] = combined_data['curveball'] * combined_data['Curveball']
combined_data['weighted_changeup'] = combined_data['changeup'] * combined_data['Changeup']
combined_data['weighted_splitter'] = combined_data['splitter'] * combined_data['Splitter']

combined_data['total_weighted_score'] = (
    combined_data['weighted_fastball'] +
    combined_data['weighted_sinker'] +
    combined_data['weighted_cutter'] +
    combined_data['weighted_slider'] +
    combined_data['weighted_sweeper'] +
    combined_data['weighted_curveball'] +
    combined_data['weighted_changeup'] +
    combined_data['weighted_splitter']
)

combined_data['total_pitches'] = (
    combined_data['Fastball'] +
    combined_data['Sinker'] +
    combined_data['Cutter'] +
    combined_data['Slider'] +
    combined_data['Sweeper'] +
    combined_data['Curveball'] +
    combined_data['Changeup'] +
    combined_data['Splitter']
)

combined_data['overall'] = combined_data['total_weighted_score'] / combined_data['total_pitches']

combined_data['overall'] = combined_data['overall'].round(2)

combined_data = combined_data[['player_name', 'overall', 'fastball', 'sinker', 'cutter', 'slider', 'sweeper', 'curveball', 'changeup', 'splitter']]

combined_data = combined_data.sort_values(by='overall', ascending=False)

combined_data.to_csv("day_pitch_scores.csv", index=False)
combined_data
# Out:
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['pred'] - df['pred'].max()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = abs(df['scaled'])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] - df['scaled'].mean()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] / df['scaled'].std()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'] = df['scaled'] * 10 + 100
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['pred'] - df['pred'].max()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = abs(df['scaled'])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] - df['scaled'].mean()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] / df['scaled'].std()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'] = df['scaled'] * 10 + 100
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['pred'] - df['pred'].max()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = abs(df['scaled'])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] - df['scaled'].mean()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] / df['scaled'].std()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'] = df['scaled'] * 10 + 100
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['pred'] - df['pred'].max()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = abs(df['scaled'])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] - df['scaled'].mean()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] / df['scaled'].std()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'] = df['scaled'] * 10 + 100
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['pred'] - df['pred'].max()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = abs(df['scaled'])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] - df['scaled'].mean()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] / df['scaled'].std()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'] = df['scaled'] * 10 + 100
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['pred'] - df['pred'].max()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = abs(df['scaled'])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] - df['scaled'].mean()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] / df['scaled'].std()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'] = df['scaled'] * 10 + 100
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['pred'] - df['pred'].max()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = abs(df['scaled'])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] - df['scaled'].mean()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] / df['scaled'].std()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'] = df['scaled'] * 10 + 100
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['pred'] - df['pred'].max()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = abs(df['scaled'])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] - df['scaled'].mean()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] / df['scaled'].std()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_1585/705413268.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'] = df['scaled'] * 10 + 100
#             player_name  overall  fastball  sinker  cutter  slider  sweeper  \
# 100        Duran, Jhoan   112.93     92.23    0.00    0.00    0.00     0.00
# 1       Fairbanks, Pete   110.29    114.07    0.00    0.00  104.35     0.00
# 2         Alcala, Jorge   109.40    112.61  105.48    0.00  102.39     0.00
# 6        Glasnow, Tyler   107.35    110.63  107.82    0.00  102.70     0.00
# 10   Rodriguez, Grayson   107.29    108.63  106.38    0.00  101.83     0.00
# ..                  ...      ...       ...     ...     ...     ...      ...
# 51        Wilson, Bryse    94.45    100.06   83.85  101.03    0.00     0.00
# 97        Herget, Kevin    94.38     93.38    0.00   95.89    0.00     0.00
# 111        Henry, Tommy    93.32     89.65   91.37    0.00   96.49     0.00
# 85      Ferguson, Caleb    87.87     95.56    0.00   81.47    0.00     0.00
# 116      Peralta, Sammy    86.23     83.76    0.00    0.00  102.30    98.27
#
#      curveball  changeup  splitter
# 100     110.33      0.00    118.69
# 1         0.00      0.00      0.00
# 2         0.00     99.85      0.00
# 6       109.71      0.00      0.00
# 10      104.16    112.05      0.00
# ..         ...       ...       ...
# 51       94.74     79.14      0.00
# 97        0.00     98.12      0.00
# 111     101.79     94.74      0.00
# 85        0.00      0.00      0.00
# 116       0.00     81.33      0.00
#
# [117 rows x 10 columns]

# %%
def get_top_individual_pitches(pitch_df, pitch_type):
    top_pitches = pitch_df[['player_name', 'pitch_type', 'release_speed','release_pos_x','release_pos_z','release_extension','pfx_x', 'pfx_z','score']]
    top_pitches = top_pitches.sort_values(by='score', ascending=False)
    top_pitches['pitch_type'] = pitch_type
    return top_pitches

top_fastball_pitches = get_top_individual_pitches(fastball_23, 'Fastball')
top_sinker_pitches = get_top_individual_pitches(sinker_23, 'Sinker')
top_cutter_pitches = get_top_individual_pitches(cutter_23, 'Cutter')
top_slider_pitches = get_top_individual_pitches(slider_23, 'Slider')
top_sweeper_pitches = get_top_individual_pitches(sweeper_23, 'Sweeper')
top_curveball_pitches = get_top_individual_pitches(curveball_23, 'Curveball')
top_changeup_pitches = get_top_individual_pitches(changeup_23, 'Changeup')
top_splitter_pitches = get_top_individual_pitches(splitter_23, 'Splitter')

top_individual_pitches = pd.concat([
    top_fastball_pitches,
    top_sinker_pitches,
    top_cutter_pitches,
    top_slider_pitches,
    top_sweeper_pitches,
    top_curveball_pitches,
    top_changeup_pitches,
    top_splitter_pitches
])
top_individual_pitches = top_individual_pitches.sort_values(by='score', ascending=False)

top_individual_pitches.to_csv("top_individual_pitches.csv", index=False)
top_individual_pitches
# Out:
#             player_name pitch_type  release_speed  release_pos_x  \
# 2871   Martinez, Justin     Sinker          100.0          -2.97
# 680        Bauers, Jake     Slider           67.5           0.94
# 2517      Alcala, Jorge   Fastball          100.1          -2.66
# 679        Bauers, Jake     Slider           66.3           0.61
# 2114     Glasnow, Tyler     Sinker           96.9          -1.85
# ...                 ...        ...            ...            ...
# 676        Bauers, Jake     Slider           68.7           0.83
# 53       Jansen, Kenley     Cutter           88.0           -2.1
# 678        Bauers, Jake     Slider           67.0           0.74
# 686        Bauers, Jake     Slider           67.3           0.75
# 1456  Verlander, Justin   Fastball           94.8          -1.26
#
#       release_pos_z  release_extension  pfx_x  pfx_z       score
# 2871           6.23                6.4  17.04   4.44  166.306022
# 680            6.92                3.8   0.24   18.0  159.029901
# 2517            6.6                5.1    7.2  17.64  156.579689
# 679            7.02                3.8   0.84  17.04  152.201743
# 2114           6.02                7.6  15.24  11.88  144.616048
# ...             ...                ...    ...    ...         ...
# 676            6.92                4.0   -5.4  16.56   13.281811
# 53             6.63                6.9  -4.44  16.32    6.724285
# 678            6.95                4.1  -3.72   12.6    0.395906
# 686            7.04                3.6  -4.68   15.0  -18.752047
# 1456           6.91                5.9  16.08  17.04  -56.874725
#
# [4226 rows x 9 columns]
