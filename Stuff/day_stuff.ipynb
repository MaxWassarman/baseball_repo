# %%
import pandas as pd
import numpy as np
from pybaseball import statcast
from pybaseball import pitching_stats
from sklearn.model_selection import train_test_split
from catboost import CatBoostRegressor
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
#Read in data
data20_22 = pd.read_csv("Statcast_2020_to_2023.csv")
data_today = statcast()

#Select columns
data20_22 = data20_22[['player_name','pitch_type','release_speed','release_pos_x','release_pos_z','release_spin_rate','release_extension','spin_axis','pfx_x', 'pfx_z','vx0','vy0','vz0','ax','ay','az','game_year','delta_run_exp']]
data_today = data_today[['player_name','pitch_type','release_speed','release_pos_x','release_pos_z','release_spin_rate','release_extension','spin_axis','pfx_x', 'pfx_z','vx0','vy0','vz0','ax','ay','az','game_year','delta_run_exp']]

#Drop na values
data20_22 = data20_22.dropna()
data_today = data_today.dropna()

#Flip to get view from pitcher
data20_22['pfx_x'] = data20_22['pfx_x'] * -1
data_today['pfx_x'] = data_today['pfx_x'] * -1

#Change to inches
data20_22['pfx_x'] = data20_22['pfx_x'] * 12
data20_22['pfx_z'] = data20_22['pfx_z'] * 12
data_today['pfx_x'] = data_today['pfx_x'] * 12
data_today['pfx_z'] = data_today['pfx_z'] * 12

#Remove unnecessary pitches
data20_22 = data20_22[data20_22.pitch_type != 'PO']
data_today = data_today[data_today.pitch_type != 'PO']

#Retag pitches
data20_22['pitch_type'] = data20_22['pitch_type'].replace(['FF','FA'], 'Fastball')
data_today['pitch_type'] = data_today['pitch_type'].replace(['FF','FA'], 'Fastball')

data20_22['pitch_type'] = data20_22['pitch_type'].replace(['SI'], 'Sinker')
data_today['pitch_type'] = data_today['pitch_type'].replace(['SI'], 'Sinker')

data20_22['pitch_type'] = data20_22['pitch_type'].replace(['FC'], 'Cutter')
data_today['pitch_type'] = data_today['pitch_type'].replace(['FC'], 'Cutter')

data20_22['pitch_type'] = data20_22['pitch_type'].replace(['SL'], 'Slider')
data_today['pitch_type'] = data_today['pitch_type'].replace(['SL'], 'Slider')

data20_22['pitch_type'] = data20_22['pitch_type'].replace(['ST'], 'Sweeper')
data_today['pitch_type'] = data_today['pitch_type'].replace(['ST'], 'Sweeper')

data20_22['pitch_type'] = data20_22['pitch_type'].replace(['CU','CS','SV','KC'], 'Curveball')
data_today['pitch_type'] = data_today['pitch_type'].replace(['CU','CS','SV','KC'], 'Curveball')

data20_22['pitch_type'] = data20_22['pitch_type'].replace(['CH','FO','EP','KN','SC'], 'Changeup')
data_today['pitch_type'] = data_today['pitch_type'].replace(['CH','FO','EP','KN','SC'], 'Changeup')

data20_22['pitch_type'] = data20_22['pitch_type'].replace(['FS'], 'Splitter')
data_today['pitch_type'] = data_today['pitch_type'].replace(['FS'], 'Splitter')
# Out:
# start_dt 2024-06-13
# end_dt 2024-06-14
# Warning: no date range supplied, assuming yesterday's date.
# This is a large query, it may take a moment to complete
# 100%|██████████| 2/2 [00:02<00:00,  1.33s/it]
# /Users/maxwassarman/miniconda3/envs/baseball/lib/python3.12/site-packages/pybaseball/statcast.py:85: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_data = pd.concat(dataframe_list, axis=0).convert_dtypes(convert_string=False)

# %%
#caculate vaa and haa
def approach_angles(df):
    yf = 17/12
    y0 = 50
    df['vy_f'] = -np.sqrt(df['vy0']**2 - (2 * df['ay'] * y0 - yf))
    df['t'] = (df['vy_f'] - df['vy0']) / df['ay']
    df['vz_f'] = df['vz0'] + (df['az'] * df['t'])
    df['vx_f'] = df['vx0'] + (df['ax'] * df['t'])

    df['vaa'] = -np.arctan(df['vz_f'] / df['vy_f']) * (180 / np.pi)
    df['haa'] = -np.arctan(df['vx_f'] / df['vy_f']) * (180 / np.pi)
    return df

data20_22 = approach_angles(data20_22)
data_today = approach_angles(data_today)


#caculate estimated axis differential and estimated spin efficiency
def axis_differential(df):
    df['calc_spin'] = np.arctan2(df['pfx_z'],df['pfx_x']) * (180 / np.pi)
    df['axis_dif'] = np.abs(df['calc_spin'] - df['spin_axis'])
    return df

data20_22 = axis_differential(data20_22)
data_today = axis_differential(data_today)


def find_most_common_fastball(df):
    fastball_types = df[df['pitch_type'].isin(['Fastball', 'Sinker', 'Cutter'])]
    most_common_fastball = fastball_types.groupby(['player_name', 'pitch_type']).size().reset_index(name='count')
    most_common_fastball = most_common_fastball.loc[most_common_fastball.groupby('player_name')['count'].idxmax()]
    most_common_fastball = most_common_fastball[['player_name', 'pitch_type']]
    most_common_fastball.rename(columns={'pitch_type': 'most_common_fastball'}, inplace=True)
    return most_common_fastball

def add_velocity_and_movement_diff(df):
    most_common_fastball = find_most_common_fastball(df)
    
    df = df.merge(most_common_fastball, on='player_name', how='left')
    
    avg_stats = df[df['pitch_type'] == df['most_common_fastball']].groupby('player_name')[['release_speed', 'pfx_x', 'pfx_z']].mean().reset_index()
    avg_stats.rename(columns={
        'release_speed': 'avg_fastball_velocity',
        'pfx_x': 'avg_fastball_pfx_x',
        'pfx_z': 'avg_fastball_pfx_z'
    }, inplace=True)
    
    df = df.merge(avg_stats, on='player_name', how='left')
    
    df['velocity_diff'] = df['avg_fastball_velocity'] - df['release_speed']
    df['horizontal_movement_diff'] = df['avg_fastball_pfx_x'] - df['pfx_x']
    df['vertical_movement_diff'] = df['avg_fastball_pfx_z'] - df['pfx_z']
    
    return df

data20_22 = add_velocity_and_movement_diff(data20_22)
data_today = add_velocity_and_movement_diff(data_today)

# %%
#Seperate pitches for different models
fastball_20_22 = data20_22[data20_22.pitch_type.isin(['Fastball'])]
fastball_23 = data_today[data_today.pitch_type.isin(['Fastball'])]

sinker_20_22 = data20_22[data20_22.pitch_type.isin(['Sinker'])]
sinker_23 = data_today[data_today.pitch_type.isin(['Sinker'])]

cutter_20_22 = data20_22[data20_22.pitch_type.isin(['Cutter'])]
cutter_23 = data_today[data_today.pitch_type.isin(['Cutter'])]

slider_20_22 = data20_22[data20_22.pitch_type.isin(['Slider'])]
slider_23 = data_today[data_today.pitch_type.isin(['Slider'])]

sweeper_20_22 = data20_22[data20_22.pitch_type.isin(['Sweeper'])]
sweeper_23 = data_today[data_today.pitch_type.isin(['Sweeper'])]

curveball_20_22 = data20_22[data20_22.pitch_type.isin(['Curveball'])]
curveball_23 = data_today[data_today.pitch_type.isin(['Curveball'])]

changeup_20_22 = data20_22[data20_22.pitch_type.isin(['Changeup'])]
changeup_23 = data_today[data_today.pitch_type.isin(['Changeup'])]

splitter_20_22 = data20_22[data20_22.pitch_type.isin(['Splitter'])]
splitter_23 = data_today[data_today.pitch_type.isin(['Splitter'])]

# %%
features = ['release_speed','release_pos_x','release_pos_z','release_extension','pfx_x', 'pfx_z','game_year', 'axis_dif', 'velocity_diff', 'horizontal_movement_diff', 'vertical_movement_diff']
#Split into train and test

fastball_x = fastball_20_22[features]
fastball_y = fastball_20_22['delta_run_exp']

x_train_fastball, x_test_fastball, y_train_fastball, y_test_fastball = train_test_split(fastball_x, fastball_y, train_size = 0.75, random_state = 12345)

sinker_x = sinker_20_22[features]
sinker_y = sinker_20_22['delta_run_exp']

x_train_sinker, x_test_sinker, y_train_sinker, y_test_sinker = train_test_split(sinker_x, sinker_y, train_size=0.75, random_state=12345)

cutter_x = cutter_20_22[features]
cutter_y = cutter_20_22['delta_run_exp']

x_train_cutter, x_test_cutter, y_train_cutter, y_test_cutter = train_test_split(cutter_x, cutter_y, train_size=0.75, random_state=12345)

slider_x = slider_20_22[features]
slider_y = slider_20_22['delta_run_exp']

x_train_slider, x_test_slider, y_train_slider, y_test_slider = train_test_split(slider_x, slider_y, train_size=0.75, random_state=12345)

sweeper_x = sweeper_20_22[features]
sweeper_y = sweeper_20_22['delta_run_exp']

x_train_sweeper, x_test_sweeper, y_train_sweeper, y_test_sweeper = train_test_split(sweeper_x, sweeper_y, train_size=0.75, random_state=12345)

curveball_x = curveball_20_22[features]
curveball_y = curveball_20_22['delta_run_exp']

x_train_curveball, x_test_curveball, y_train_curveball, y_test_curveball = train_test_split(curveball_x, curveball_y, train_size=0.75, random_state=12345)

changeup_x = changeup_20_22[features]
changeup_y = changeup_20_22['delta_run_exp']

x_train_changeup, x_test_changeup, y_train_changeup, y_test_changeup = train_test_split(changeup_x, changeup_y, train_size=0.75, random_state=12345)

splitter_x = splitter_20_22[features]
splitter_y = splitter_20_22['delta_run_exp']

x_train_splitter, x_test_splitter, y_train_splitter, y_test_splitter = train_test_split(splitter_x, splitter_y, train_size=0.75, random_state=12345)

# %%
#Set params for catboost models (Random ones right now)
params = {
    'iterations': 500,
    'depth': 5,
    'learning_rate': 0.11, #manual checks with FIP corr both predictive and descriptive
    'random_seed': 12345    
}

#Train each model

#Fastball
fastball_model = CatBoostRegressor(**params)
fastball_model.fit(x_train_fastball, y_train_fastball)

#Sinker
sinker_model = CatBoostRegressor(**params)
sinker_model.fit(x_train_sinker, y_train_sinker)

#Cutter
cutter_model = CatBoostRegressor(**params)
cutter_model.fit(x_train_cutter, y_train_cutter)

#Slider
slider_model = CatBoostRegressor(**params)
slider_model.fit(x_train_slider, y_train_slider)

#Sweeper
sweeper_model = CatBoostRegressor(**params)
sweeper_model.fit(x_train_sweeper, y_train_sweeper)

#Curveball
curveball_model = CatBoostRegressor(**params)
curveball_model.fit(x_train_curveball, y_train_curveball)

#Changeup
changeup_model = CatBoostRegressor(**params)
changeup_model.fit(x_train_changeup, y_train_changeup)

#Splitter
splitter_model = CatBoostRegressor(**params)
splitter_model.fit(x_train_splitter, y_train_splitter)
# Out:
# 0:	learn: 0.2412655	total: 78.2ms	remaining: 39s
# 1:	learn: 0.2412441	total: 98.4ms	remaining: 24.5s
# 2:	learn: 0.2412333	total: 140ms	remaining: 23.1s
# 3:	learn: 0.2412196	total: 174ms	remaining: 21.6s
# 4:	learn: 0.2412051	total: 195ms	remaining: 19.3s
# 5:	learn: 0.2411924	total: 210ms	remaining: 17.3s
# 6:	learn: 0.2411851	total: 228ms	remaining: 16s
# 7:	learn: 0.2411763	total: 246ms	remaining: 15.1s
# 8:	learn: 0.2411690	total: 261ms	remaining: 14.2s
# 9:	learn: 0.2411610	total: 276ms	remaining: 13.5s
# 10:	learn: 0.2411541	total: 290ms	remaining: 12.9s
# 11:	learn: 0.2411482	total: 307ms	remaining: 12.5s
# 12:	learn: 0.2411425	total: 324ms	remaining: 12.1s
# 13:	learn: 0.2411363	total: 340ms	remaining: 11.8s
# 14:	learn: 0.2411325	total: 357ms	remaining: 11.6s
# 15:	learn: 0.2411277	total: 375ms	remaining: 11.4s
# 16:	learn: 0.2411223	total: 393ms	remaining: 11.2s
# 17:	learn: 0.2411171	total: 410ms	remaining: 11s
# 18:	learn: 0.2411108	total: 431ms	remaining: 10.9s
# 19:	learn: 0.2411060	total: 449ms	remaining: 10.8s
# 20:	learn: 0.2411030	total: 467ms	remaining: 10.7s
# 21:	learn: 0.2411001	total: 490ms	remaining: 10.6s
# 22:	learn: 0.2410949	total: 510ms	remaining: 10.6s
# 23:	learn: 0.2410903	total: 532ms	remaining: 10.5s
# 24:	learn: 0.2410864	total: 552ms	remaining: 10.5s
# 25:	learn: 0.2410820	total: 571ms	remaining: 10.4s
# 26:	learn: 0.2410788	total: 590ms	remaining: 10.3s
# 27:	learn: 0.2410751	total: 608ms	remaining: 10.2s
# 28:	learn: 0.2410727	total: 623ms	remaining: 10.1s
# 29:	learn: 0.2410697	total: 637ms	remaining: 9.97s
# 30:	learn: 0.2410662	total: 652ms	remaining: 9.87s
# 31:	learn: 0.2410621	total: 669ms	remaining: 9.79s
# 32:	learn: 0.2410589	total: 685ms	remaining: 9.69s
# 33:	learn: 0.2410559	total: 702ms	remaining: 9.62s
# 34:	learn: 0.2410531	total: 721ms	remaining: 9.57s
# 35:	learn: 0.2410492	total: 741ms	remaining: 9.55s
# 36:	learn: 0.2410471	total: 761ms	remaining: 9.53s
# 37:	learn: 0.2410455	total: 781ms	remaining: 9.49s
# 38:	learn: 0.2410431	total: 797ms	remaining: 9.43s
# 39:	learn: 0.2410401	total: 815ms	remaining: 9.37s
# 40:	learn: 0.2410377	total: 832ms	remaining: 9.31s
# 41:	learn: 0.2410351	total: 848ms	remaining: 9.25s
# 42:	learn: 0.2410324	total: 864ms	remaining: 9.18s
# 43:	learn: 0.2410286	total: 881ms	remaining: 9.13s
# 44:	learn: 0.2410259	total: 897ms	remaining: 9.07s
# 45:	learn: 0.2410231	total: 914ms	remaining: 9.02s
# 46:	learn: 0.2410194	total: 932ms	remaining: 8.99s
# 47:	learn: 0.2410158	total: 948ms	remaining: 8.93s
# 48:	learn: 0.2410138	total: 964ms	remaining: 8.87s
# 49:	learn: 0.2410116	total: 980ms	remaining: 8.82s
# 50:	learn: 0.2410091	total: 996ms	remaining: 8.77s
# 51:	learn: 0.2410064	total: 1.01s	remaining: 8.73s
# 52:	learn: 0.2410033	total: 1.03s	remaining: 8.69s
# 53:	learn: 0.2410013	total: 1.05s	remaining: 8.65s
# 54:	learn: 0.2409983	total: 1.06s	remaining: 8.61s
# 55:	learn: 0.2409959	total: 1.08s	remaining: 8.57s
# 56:	learn: 0.2409922	total: 1.1s	remaining: 8.52s
# 57:	learn: 0.2409900	total: 1.11s	remaining: 8.48s
# 58:	learn: 0.2409867	total: 1.13s	remaining: 8.45s
# 59:	learn: 0.2409844	total: 1.15s	remaining: 8.43s
# 60:	learn: 0.2409821	total: 1.17s	remaining: 8.38s
# 61:	learn: 0.2409790	total: 1.18s	remaining: 8.34s
# 62:	learn: 0.2409781	total: 1.2s	remaining: 8.31s
# 63:	learn: 0.2409746	total: 1.22s	remaining: 8.28s
# 64:	learn: 0.2409724	total: 1.23s	remaining: 8.24s
# 65:	learn: 0.2409709	total: 1.25s	remaining: 8.2s
# 66:	learn: 0.2409681	total: 1.26s	remaining: 8.17s
# 67:	learn: 0.2409671	total: 1.28s	remaining: 8.13s
# 68:	learn: 0.2409658	total: 1.3s	remaining: 8.1s
# 69:	learn: 0.2409645	total: 1.31s	remaining: 8.07s
# 70:	learn: 0.2409622	total: 1.33s	remaining: 8.03s
# 71:	learn: 0.2409605	total: 1.35s	remaining: 8.01s
# 72:	learn: 0.2409583	total: 1.36s	remaining: 7.98s
# 73:	learn: 0.2409560	total: 1.38s	remaining: 7.95s
# 74:	learn: 0.2409538	total: 1.4s	remaining: 7.93s
# 75:	learn: 0.2409523	total: 1.41s	remaining: 7.88s
# 76:	learn: 0.2409493	total: 1.43s	remaining: 7.85s
# 77:	learn: 0.2409466	total: 1.44s	remaining: 7.81s
# 78:	learn: 0.2409447	total: 1.46s	remaining: 7.78s
# 79:	learn: 0.2409420	total: 1.48s	remaining: 7.75s
# 80:	learn: 0.2409405	total: 1.49s	remaining: 7.71s
# 81:	learn: 0.2409378	total: 1.51s	remaining: 7.68s
# 82:	learn: 0.2409328	total: 1.52s	remaining: 7.64s
# 83:	learn: 0.2409302	total: 1.54s	remaining: 7.62s
# 84:	learn: 0.2409287	total: 1.55s	remaining: 7.58s
# 85:	learn: 0.2409254	total: 1.57s	remaining: 7.55s
# 86:	learn: 0.2409222	total: 1.58s	remaining: 7.52s
# 87:	learn: 0.2409196	total: 1.6s	remaining: 7.48s
# 88:	learn: 0.2409166	total: 1.61s	remaining: 7.45s
# 89:	learn: 0.2409151	total: 1.63s	remaining: 7.43s
# 90:	learn: 0.2409127	total: 1.66s	remaining: 7.45s
# 91:	learn: 0.2409110	total: 1.69s	remaining: 7.48s
# 92:	learn: 0.2409068	total: 1.71s	remaining: 7.47s
# 93:	learn: 0.2409056	total: 1.73s	remaining: 7.45s
# 94:	learn: 0.2409034	total: 1.74s	remaining: 7.42s
# 95:	learn: 0.2409024	total: 1.76s	remaining: 7.39s
# 96:	learn: 0.2409011	total: 1.77s	remaining: 7.38s
# 97:	learn: 0.2408993	total: 1.8s	remaining: 7.39s
# 98:	learn: 0.2408979	total: 1.82s	remaining: 7.37s
# 99:	learn: 0.2408964	total: 1.83s	remaining: 7.34s
# 100:	learn: 0.2408933	total: 1.85s	remaining: 7.31s
# 101:	learn: 0.2408904	total: 1.87s	remaining: 7.28s
# 102:	learn: 0.2408887	total: 1.88s	remaining: 7.25s
# 103:	learn: 0.2408846	total: 1.89s	remaining: 7.21s
# 104:	learn: 0.2408819	total: 1.91s	remaining: 7.2s
# 105:	learn: 0.2408805	total: 1.97s	remaining: 7.32s
# 106:	learn: 0.2408786	total: 2s	remaining: 7.36s
# 107:	learn: 0.2408769	total: 2.02s	remaining: 7.34s
# 108:	learn: 0.2408762	total: 2.04s	remaining: 7.32s
# 109:	learn: 0.2408733	total: 2.06s	remaining: 7.3s
# 110:	learn: 0.2408708	total: 2.07s	remaining: 7.27s
# 111:	learn: 0.2408680	total: 2.09s	remaining: 7.24s
# 112:	learn: 0.2408665	total: 2.11s	remaining: 7.21s
# 113:	learn: 0.2408653	total: 2.12s	remaining: 7.18s
# 114:	learn: 0.2408645	total: 2.13s	remaining: 7.15s
# 115:	learn: 0.2408622	total: 2.15s	remaining: 7.12s
# 116:	learn: 0.2408601	total: 2.17s	remaining: 7.09s
# 117:	learn: 0.2408582	total: 2.18s	remaining: 7.06s
# 118:	learn: 0.2408574	total: 2.19s	remaining: 7.03s
# 119:	learn: 0.2408546	total: 2.21s	remaining: 7s
# 120:	learn: 0.2408532	total: 2.22s	remaining: 6.97s
# 121:	learn: 0.2408521	total: 2.24s	remaining: 6.94s
# 122:	learn: 0.2408490	total: 2.26s	remaining: 6.91s
# 123:	learn: 0.2408453	total: 2.27s	remaining: 6.88s
# 124:	learn: 0.2408422	total: 2.29s	remaining: 6.86s
# 125:	learn: 0.2408405	total: 2.3s	remaining: 6.83s
# 126:	learn: 0.2408392	total: 2.32s	remaining: 6.8s
# 127:	learn: 0.2408362	total: 2.33s	remaining: 6.78s
# 128:	learn: 0.2408345	total: 2.35s	remaining: 6.76s
# 129:	learn: 0.2408306	total: 2.37s	remaining: 6.73s
# 130:	learn: 0.2408278	total: 2.38s	remaining: 6.71s
# 131:	learn: 0.2408258	total: 2.4s	remaining: 6.68s
# 132:	learn: 0.2408227	total: 2.41s	remaining: 6.66s
# 133:	learn: 0.2408178	total: 2.42s	remaining: 6.63s
# 134:	learn: 0.2408165	total: 2.44s	remaining: 6.59s
# 135:	learn: 0.2408155	total: 2.45s	remaining: 6.57s
# 136:	learn: 0.2408136	total: 2.47s	remaining: 6.54s
# 137:	learn: 0.2408105	total: 2.48s	remaining: 6.51s
# 138:	learn: 0.2408084	total: 2.5s	remaining: 6.49s
# 139:	learn: 0.2408064	total: 2.51s	remaining: 6.46s
# 140:	learn: 0.2408047	total: 2.53s	remaining: 6.44s
# 141:	learn: 0.2408014	total: 2.54s	remaining: 6.41s
# 142:	learn: 0.2407991	total: 2.56s	remaining: 6.38s
# 143:	learn: 0.2407976	total: 2.57s	remaining: 6.35s
# 144:	learn: 0.2407955	total: 2.58s	remaining: 6.33s
# 145:	learn: 0.2407936	total: 2.6s	remaining: 6.29s
# 146:	learn: 0.2407909	total: 2.61s	remaining: 6.27s
# 147:	learn: 0.2407882	total: 2.63s	remaining: 6.24s
# 148:	learn: 0.2407876	total: 2.64s	remaining: 6.21s
# 149:	learn: 0.2407851	total: 2.65s	remaining: 6.19s
# 150:	learn: 0.2407809	total: 2.67s	remaining: 6.17s
# 151:	learn: 0.2407778	total: 2.68s	remaining: 6.14s
# 152:	learn: 0.2407747	total: 2.7s	remaining: 6.13s
# 153:	learn: 0.2407725	total: 2.71s	remaining: 6.1s
# 154:	learn: 0.2407707	total: 2.73s	remaining: 6.08s
# 155:	learn: 0.2407680	total: 2.74s	remaining: 6.05s
# 156:	learn: 0.2407665	total: 2.76s	remaining: 6.03s
# 157:	learn: 0.2407636	total: 2.77s	remaining: 6s
# 158:	learn: 0.2407615	total: 2.79s	remaining: 5.97s
# 159:	learn: 0.2407575	total: 2.8s	remaining: 5.95s
# 160:	learn: 0.2407548	total: 2.81s	remaining: 5.93s
# 161:	learn: 0.2407542	total: 2.83s	remaining: 5.9s
# 162:	learn: 0.2407532	total: 2.84s	remaining: 5.88s
# 163:	learn: 0.2407512	total: 2.87s	remaining: 5.87s
# 164:	learn: 0.2407481	total: 2.89s	remaining: 5.87s
# 165:	learn: 0.2407450	total: 2.92s	remaining: 5.87s
# 166:	learn: 0.2407427	total: 2.94s	remaining: 5.86s
# 167:	learn: 0.2407396	total: 2.95s	remaining: 5.84s
# 168:	learn: 0.2407355	total: 2.97s	remaining: 5.82s
# 169:	learn: 0.2407332	total: 2.98s	remaining: 5.79s
# 170:	learn: 0.2407313	total: 3s	remaining: 5.77s
# 171:	learn: 0.2407293	total: 3.01s	remaining: 5.75s
# 172:	learn: 0.2407259	total: 3.03s	remaining: 5.72s
# 173:	learn: 0.2407243	total: 3.04s	remaining: 5.7s
# 174:	learn: 0.2407206	total: 3.06s	remaining: 5.68s
# 175:	learn: 0.2407180	total: 3.07s	remaining: 5.66s
# 176:	learn: 0.2407151	total: 3.09s	remaining: 5.64s
# 177:	learn: 0.2407122	total: 3.1s	remaining: 5.62s
# 178:	learn: 0.2407105	total: 3.12s	remaining: 5.59s
# 179:	learn: 0.2407077	total: 3.13s	remaining: 5.57s
# 180:	learn: 0.2407058	total: 3.15s	remaining: 5.54s
# 181:	learn: 0.2407034	total: 3.16s	remaining: 5.52s
# 182:	learn: 0.2407013	total: 3.17s	remaining: 5.5s
# 183:	learn: 0.2406991	total: 3.19s	remaining: 5.47s
# 184:	learn: 0.2406968	total: 3.2s	remaining: 5.45s
# 185:	learn: 0.2406951	total: 3.21s	remaining: 5.43s
# 186:	learn: 0.2406919	total: 3.23s	remaining: 5.41s
# 187:	learn: 0.2406880	total: 3.25s	remaining: 5.39s
# 188:	learn: 0.2406866	total: 3.26s	remaining: 5.36s
# 189:	learn: 0.2406840	total: 3.27s	remaining: 5.34s
# 190:	learn: 0.2406818	total: 3.29s	remaining: 5.33s
# 191:	learn: 0.2406795	total: 3.31s	remaining: 5.31s
# 192:	learn: 0.2406776	total: 3.33s	remaining: 5.29s
# 193:	learn: 0.2406764	total: 3.34s	remaining: 5.27s
# 194:	learn: 0.2406738	total: 3.35s	remaining: 5.25s
# 195:	learn: 0.2406705	total: 3.37s	remaining: 5.23s
# 196:	learn: 0.2406688	total: 3.39s	remaining: 5.21s
# 197:	learn: 0.2406650	total: 3.4s	remaining: 5.19s
# 198:	learn: 0.2406626	total: 3.42s	remaining: 5.17s
# 199:	learn: 0.2406606	total: 3.43s	remaining: 5.15s
# 200:	learn: 0.2406589	total: 3.45s	remaining: 5.13s
# 201:	learn: 0.2406569	total: 3.46s	remaining: 5.11s
# 202:	learn: 0.2406547	total: 3.48s	remaining: 5.09s
# 203:	learn: 0.2406529	total: 3.49s	remaining: 5.07s
# 204:	learn: 0.2406520	total: 3.51s	remaining: 5.05s
# 205:	learn: 0.2406493	total: 3.52s	remaining: 5.03s
# 206:	learn: 0.2406479	total: 3.54s	remaining: 5.01s
# 207:	learn: 0.2406467	total: 3.55s	remaining: 4.99s
# 208:	learn: 0.2406436	total: 3.57s	remaining: 4.96s
# 209:	learn: 0.2406408	total: 3.58s	remaining: 4.95s
# 210:	learn: 0.2406386	total: 3.6s	remaining: 4.93s
# 211:	learn: 0.2406356	total: 3.62s	remaining: 4.91s
# 212:	learn: 0.2406338	total: 3.63s	remaining: 4.89s
# 213:	learn: 0.2406310	total: 3.65s	remaining: 4.87s
# 214:	learn: 0.2406292	total: 3.66s	remaining: 4.85s
# 215:	learn: 0.2406268	total: 3.68s	remaining: 4.83s
# 216:	learn: 0.2406255	total: 3.69s	remaining: 4.81s
# 217:	learn: 0.2406238	total: 3.71s	remaining: 4.79s
# 218:	learn: 0.2406216	total: 3.72s	remaining: 4.77s
# 219:	learn: 0.2406192	total: 3.73s	remaining: 4.75s
# 220:	learn: 0.2406173	total: 3.75s	remaining: 4.73s
# 221:	learn: 0.2406154	total: 3.76s	remaining: 4.71s
# 222:	learn: 0.2406122	total: 3.78s	remaining: 4.69s
# 223:	learn: 0.2406102	total: 3.79s	remaining: 4.67s
# 224:	learn: 0.2406092	total: 3.81s	remaining: 4.66s
# 225:	learn: 0.2406056	total: 3.83s	remaining: 4.64s
# 226:	learn: 0.2406033	total: 3.84s	remaining: 4.62s
# 227:	learn: 0.2406008	total: 3.86s	remaining: 4.6s
# 228:	learn: 0.2405986	total: 3.87s	remaining: 4.58s
# 229:	learn: 0.2405948	total: 3.89s	remaining: 4.56s
# 230:	learn: 0.2405926	total: 3.9s	remaining: 4.54s
# 231:	learn: 0.2405921	total: 3.91s	remaining: 4.52s
# 232:	learn: 0.2405910	total: 3.93s	remaining: 4.5s
# 233:	learn: 0.2405898	total: 3.94s	remaining: 4.48s
# 234:	learn: 0.2405863	total: 3.96s	remaining: 4.46s
# 235:	learn: 0.2405846	total: 3.97s	remaining: 4.44s
# 236:	learn: 0.2405812	total: 3.99s	remaining: 4.42s
# 237:	learn: 0.2405781	total: 4s	remaining: 4.4s
# 238:	learn: 0.2405760	total: 4.02s	remaining: 4.39s
# 239:	learn: 0.2405737	total: 4.04s	remaining: 4.37s
# 286:	learn: 0.2404706	total: 4.78s	remaining: 3.55s
# 287:	learn: 0.2404696	total: 4.8s	remaining: 3.53s
# 288:	learn: 0.2404676	total: 4.82s	remaining: 3.52s
# 289:	learn: 0.2404655	total: 4.83s	remaining: 3.5s
# 290:	learn: 0.2404622	total: 4.86s	remaining: 3.49s
# 291:	learn: 0.2404602	total: 4.88s	remaining: 3.48s
# 292:	learn: 0.2404579	total: 4.9s	remaining: 3.46s
# 293:	learn: 0.2404548	total: 4.92s	remaining: 3.44s
# 294:	learn: 0.2404537	total: 4.93s	remaining: 3.43s
# 295:	learn: 0.2404517	total: 4.95s	remaining: 3.41s
# 296:	learn: 0.2404475	total: 4.96s	remaining: 3.39s
# 297:	learn: 0.2404448	total: 4.97s	remaining: 3.37s
# 298:	learn: 0.2404418	total: 4.99s	remaining: 3.35s
# 299:	learn: 0.2404403	total: 5.01s	remaining: 3.34s
# 300:	learn: 0.2404371	total: 5.03s	remaining: 3.32s
# 301:	learn: 0.2404355	total: 5.04s	remaining: 3.31s
# 302:	learn: 0.2404326	total: 5.07s	remaining: 3.29s
# 303:	learn: 0.2404308	total: 5.09s	remaining: 3.28s
# 304:	learn: 0.2404279	total: 5.11s	remaining: 3.27s
# 305:	learn: 0.2404259	total: 5.13s	remaining: 3.25s
# 306:	learn: 0.2404243	total: 5.14s	remaining: 3.23s
# 307:	learn: 0.2404209	total: 5.16s	remaining: 3.21s
# 308:	learn: 0.2404182	total: 5.17s	remaining: 3.2s
# 309:	learn: 0.2404160	total: 5.19s	remaining: 3.18s
# 310:	learn: 0.2404151	total: 5.2s	remaining: 3.16s
# 311:	learn: 0.2404114	total: 5.22s	remaining: 3.14s
# 312:	learn: 0.2404093	total: 5.23s	remaining: 3.13s
# 313:	learn: 0.2404068	total: 5.25s	remaining: 3.11s
# 314:	learn: 0.2404046	total: 5.26s	remaining: 3.09s
# 315:	learn: 0.2404022	total: 5.28s	remaining: 3.08s
# 316:	learn: 0.2404003	total: 5.3s	remaining: 3.06s
# 317:	learn: 0.2403980	total: 5.32s	remaining: 3.04s
# 318:	learn: 0.2403944	total: 5.33s	remaining: 3.02s
# 319:	learn: 0.2403923	total: 5.35s	remaining: 3.01s
# 320:	learn: 0.2403887	total: 5.36s	remaining: 2.99s
# 321:	learn: 0.2403869	total: 5.38s	remaining: 2.97s
# 322:	learn: 0.2403853	total: 5.39s	remaining: 2.96s
# 323:	learn: 0.2403830	total: 5.41s	remaining: 2.94s
# 324:	learn: 0.2403808	total: 5.42s	remaining: 2.92s
# 325:	learn: 0.2403797	total: 5.44s	remaining: 2.9s
# 326:	learn: 0.2403793	total: 5.45s	remaining: 2.88s
# 327:	learn: 0.2403775	total: 5.47s	remaining: 2.87s
# 328:	learn: 0.2403771	total: 5.49s	remaining: 2.85s
# 329:	learn: 0.2403744	total: 5.5s	remaining: 2.83s
# 330:	learn: 0.2403735	total: 5.51s	remaining: 2.82s
# 331:	learn: 0.2403708	total: 5.53s	remaining: 2.8s
# 332:	learn: 0.2403690	total: 5.55s	remaining: 2.78s
# 333:	learn: 0.2403667	total: 5.56s	remaining: 2.76s
# 334:	learn: 0.2403632	total: 5.58s	remaining: 2.75s
# 335:	learn: 0.2403591	total: 5.6s	remaining: 2.73s
# 336:	learn: 0.2403569	total: 5.61s	remaining: 2.71s
# 337:	learn: 0.2403531	total: 5.63s	remaining: 2.7s
# 338:	learn: 0.2403519	total: 5.64s	remaining: 2.68s
# 339:	learn: 0.2403498	total: 5.66s	remaining: 2.66s
# 340:	learn: 0.2403476	total: 5.68s	remaining: 2.65s
# 341:	learn: 0.2403459	total: 5.72s	remaining: 2.64s
# 342:	learn: 0.2403433	total: 5.75s	remaining: 2.63s
# 343:	learn: 0.2403405	total: 5.77s	remaining: 2.62s
# 344:	learn: 0.2403383	total: 5.79s	remaining: 2.6s
# 345:	learn: 0.2403366	total: 5.81s	remaining: 2.59s
# 346:	learn: 0.2403339	total: 5.83s	remaining: 2.57s
# 347:	learn: 0.2403319	total: 5.84s	remaining: 2.55s
# 348:	learn: 0.2403301	total: 5.86s	remaining: 2.54s
# 349:	learn: 0.2403280	total: 5.88s	remaining: 2.52s
# 350:	learn: 0.2403265	total: 5.91s	remaining: 2.51s
# 351:	learn: 0.2403241	total: 5.93s	remaining: 2.49s
# 352:	learn: 0.2403216	total: 5.95s	remaining: 2.48s
# 353:	learn: 0.2403195	total: 5.96s	remaining: 2.46s
# 354:	learn: 0.2403184	total: 5.97s	remaining: 2.44s
# 355:	learn: 0.2403168	total: 5.99s	remaining: 2.42s
# 356:	learn: 0.2403153	total: 6s	remaining: 2.4s
# 357:	learn: 0.2403138	total: 6.02s	remaining: 2.39s
# 358:	learn: 0.2403127	total: 6.03s	remaining: 2.37s
# 359:	learn: 0.2403105	total: 6.05s	remaining: 2.35s
# 360:	learn: 0.2403083	total: 6.06s	remaining: 2.33s
# 361:	learn: 0.2403063	total: 6.08s	remaining: 2.32s
# 362:	learn: 0.2403043	total: 6.1s	remaining: 2.3s
# 363:	learn: 0.2403017	total: 6.11s	remaining: 2.28s
# 364:	learn: 0.2402993	total: 6.13s	remaining: 2.27s
# 365:	learn: 0.2402984	total: 6.14s	remaining: 2.25s
# 366:	learn: 0.2402949	total: 6.15s	remaining: 2.23s
# 367:	learn: 0.2402931	total: 6.17s	remaining: 2.21s
# 368:	learn: 0.2402911	total: 6.18s	remaining: 2.19s
# 369:	learn: 0.2402885	total: 6.19s	remaining: 2.17s
# 370:	learn: 0.2402871	total: 6.21s	remaining: 2.16s
# 371:	learn: 0.2402849	total: 6.22s	remaining: 2.14s
# 372:	learn: 0.2402830	total: 6.23s	remaining: 2.12s
# 373:	learn: 0.2402810	total: 6.24s	remaining: 2.1s
# 374:	learn: 0.2402786	total: 6.26s	remaining: 2.08s
# 375:	learn: 0.2402781	total: 6.27s	remaining: 2.07s
# 376:	learn: 0.2402766	total: 6.28s	remaining: 2.05s
# 377:	learn: 0.2402744	total: 6.3s	remaining: 2.03s
# 378:	learn: 0.2402726	total: 6.31s	remaining: 2.02s
# 379:	learn: 0.2402714	total: 6.33s	remaining: 2s
# 380:	learn: 0.2402696	total: 6.34s	remaining: 1.98s
# 381:	learn: 0.2402680	total: 6.36s	remaining: 1.96s
# 382:	learn: 0.2402657	total: 6.37s	remaining: 1.95s
# 383:	learn: 0.2402646	total: 6.38s	remaining: 1.93s
# 384:	learn: 0.2402619	total: 6.4s	remaining: 1.91s
# 385:	learn: 0.2402599	total: 6.41s	remaining: 1.89s
# 386:	learn: 0.2402585	total: 6.44s	remaining: 1.88s
# 387:	learn: 0.2402560	total: 6.45s	remaining: 1.86s
# 388:	learn: 0.2402529	total: 6.47s	remaining: 1.84s
# 389:	learn: 0.2402511	total: 6.48s	remaining: 1.83s
# 390:	learn: 0.2402493	total: 6.5s	remaining: 1.81s
# 391:	learn: 0.2402469	total: 6.51s	remaining: 1.79s
# 392:	learn: 0.2402445	total: 6.53s	remaining: 1.78s
# 393:	learn: 0.2402422	total: 6.54s	remaining: 1.76s
# 394:	learn: 0.2402407	total: 6.56s	remaining: 1.74s
# 395:	learn: 0.2402376	total: 6.57s	remaining: 1.73s
# 396:	learn: 0.2402362	total: 6.59s	remaining: 1.71s
# 397:	learn: 0.2402346	total: 6.6s	remaining: 1.69s
# 398:	learn: 0.2402320	total: 6.62s	remaining: 1.67s
# 399:	learn: 0.2402301	total: 6.63s	remaining: 1.66s
# 400:	learn: 0.2402284	total: 6.64s	remaining: 1.64s
# 401:	learn: 0.2402270	total: 6.66s	remaining: 1.62s
# 402:	learn: 0.2402248	total: 6.67s	remaining: 1.61s
# 403:	learn: 0.2402231	total: 6.69s	remaining: 1.59s
# 404:	learn: 0.2402204	total: 6.71s	remaining: 1.57s
# 405:	learn: 0.2402177	total: 6.72s	remaining: 1.56s
# 406:	learn: 0.2402148	total: 6.74s	remaining: 1.54s
# 407:	learn: 0.2402137	total: 6.75s	remaining: 1.52s
# 408:	learn: 0.2402117	total: 6.77s	remaining: 1.51s
# 409:	learn: 0.2402100	total: 6.78s	remaining: 1.49s
# 410:	learn: 0.2402089	total: 6.8s	remaining: 1.47s
# 411:	learn: 0.2402068	total: 6.81s	remaining: 1.45s
# 412:	learn: 0.2402049	total: 6.83s	remaining: 1.44s
# 413:	learn: 0.2402023	total: 6.84s	remaining: 1.42s
# 414:	learn: 0.2402007	total: 6.85s	remaining: 1.4s
# 415:	learn: 0.2401978	total: 6.87s	remaining: 1.39s
# 416:	learn: 0.2401970	total: 6.88s	remaining: 1.37s
# 417:	learn: 0.2401946	total: 6.9s	remaining: 1.35s
# 418:	learn: 0.2401926	total: 6.92s	remaining: 1.34s
# 419:	learn: 0.2401910	total: 6.94s	remaining: 1.32s
# 420:	learn: 0.2401884	total: 6.96s	remaining: 1.3s
# 421:	learn: 0.2401864	total: 6.97s	remaining: 1.29s
# 422:	learn: 0.2401842	total: 6.99s	remaining: 1.27s
# 423:	learn: 0.2401826	total: 7s	remaining: 1.25s
# 424:	learn: 0.2401813	total: 7.02s	remaining: 1.24s
# 425:	learn: 0.2401787	total: 7.03s	remaining: 1.22s
# 473:	learn: 0.2400890	total: 7.75s	remaining: 425ms
# 474:	learn: 0.2400867	total: 7.76s	remaining: 409ms
# 475:	learn: 0.2400838	total: 7.78s	remaining: 392ms
# 476:	learn: 0.2400831	total: 7.79s	remaining: 376ms
# 477:	learn: 0.2400804	total: 7.81s	remaining: 359ms
# 478:	learn: 0.2400787	total: 7.82s	remaining: 343ms
# 479:	learn: 0.2400769	total: 7.83s	remaining: 326ms
# 480:	learn: 0.2400750	total: 7.85s	remaining: 310ms
# 481:	learn: 0.2400730	total: 7.86s	remaining: 294ms
# 482:	learn: 0.2400725	total: 7.87s	remaining: 277ms
# 483:	learn: 0.2400716	total: 7.89s	remaining: 261ms
# 484:	learn: 0.2400688	total: 7.91s	remaining: 244ms
# 485:	learn: 0.2400667	total: 7.92s	remaining: 228ms
# 486:	learn: 0.2400642	total: 7.94s	remaining: 212ms
# 487:	learn: 0.2400614	total: 7.96s	remaining: 196ms
# 488:	learn: 0.2400589	total: 7.98s	remaining: 180ms
# 489:	learn: 0.2400572	total: 8s	remaining: 163ms
# 490:	learn: 0.2400557	total: 8.02s	remaining: 147ms
# 491:	learn: 0.2400538	total: 8.04s	remaining: 131ms
# 492:	learn: 0.2400520	total: 8.05s	remaining: 114ms
# 493:	learn: 0.2400503	total: 8.07s	remaining: 98ms
# 494:	learn: 0.2400480	total: 8.08s	remaining: 81.6ms
# 495:	learn: 0.2400428	total: 8.1s	remaining: 65.3ms
# 496:	learn: 0.2400403	total: 8.11s	remaining: 49ms
# 497:	learn: 0.2400391	total: 8.13s	remaining: 32.6ms
# 498:	learn: 0.2400374	total: 8.14s	remaining: 16.3ms
# 499:	learn: 0.2400360	total: 8.15s	remaining: 0us
# 0:	learn: 0.2536429	total: 9.03ms	remaining: 4.5s
# 1:	learn: 0.2536340	total: 17.7ms	remaining: 4.4s
# 2:	learn: 0.2536271	total: 25.6ms	remaining: 4.24s
# 3:	learn: 0.2536205	total: 32.7ms	remaining: 4.05s
# 4:	learn: 0.2536142	total: 41.1ms	remaining: 4.07s
# 5:	learn: 0.2536069	total: 48.4ms	remaining: 3.99s
# 6:	learn: 0.2536020	total: 55.5ms	remaining: 3.91s
# 7:	learn: 0.2535953	total: 62.6ms	remaining: 3.85s
# 8:	learn: 0.2535876	total: 70.6ms	remaining: 3.85s
# 9:	learn: 0.2535810	total: 77.4ms	remaining: 3.79s
# 10:	learn: 0.2535756	total: 84.6ms	remaining: 3.76s
# 11:	learn: 0.2535689	total: 93.8ms	remaining: 3.81s
# 12:	learn: 0.2535647	total: 102ms	remaining: 3.83s
# 13:	learn: 0.2535581	total: 110ms	remaining: 3.82s
# 14:	learn: 0.2535541	total: 123ms	remaining: 3.97s
# 15:	learn: 0.2535484	total: 132ms	remaining: 3.99s
# 16:	learn: 0.2535456	total: 146ms	remaining: 4.14s
# 17:	learn: 0.2535412	total: 158ms	remaining: 4.24s
# 18:	learn: 0.2535363	total: 173ms	remaining: 4.38s
# 19:	learn: 0.2535325	total: 184ms	remaining: 4.42s
# 20:	learn: 0.2535264	total: 196ms	remaining: 4.46s
# 21:	learn: 0.2535192	total: 206ms	remaining: 4.47s
# 22:	learn: 0.2535148	total: 215ms	remaining: 4.46s
# 23:	learn: 0.2535131	total: 222ms	remaining: 4.41s
# 24:	learn: 0.2535073	total: 230ms	remaining: 4.36s
# 25:	learn: 0.2535020	total: 239ms	remaining: 4.35s
# 26:	learn: 0.2534961	total: 245ms	remaining: 4.3s
# 27:	learn: 0.2534933	total: 253ms	remaining: 4.26s
# 28:	learn: 0.2534863	total: 259ms	remaining: 4.21s
# 29:	learn: 0.2534832	total: 267ms	remaining: 4.18s
# 30:	learn: 0.2534791	total: 274ms	remaining: 4.15s
# 31:	learn: 0.2534742	total: 281ms	remaining: 4.11s
# 32:	learn: 0.2534700	total: 289ms	remaining: 4.09s
# 33:	learn: 0.2534682	total: 295ms	remaining: 4.05s
# 34:	learn: 0.2534643	total: 303ms	remaining: 4.03s
# 35:	learn: 0.2534624	total: 311ms	remaining: 4.01s
# 36:	learn: 0.2534562	total: 319ms	remaining: 3.99s
# 37:	learn: 0.2534518	total: 326ms	remaining: 3.96s
# 38:	learn: 0.2534469	total: 334ms	remaining: 3.94s
# 39:	learn: 0.2534428	total: 342ms	remaining: 3.93s
# 40:	learn: 0.2534378	total: 349ms	remaining: 3.91s
# 41:	learn: 0.2534354	total: 357ms	remaining: 3.89s
# 42:	learn: 0.2534315	total: 365ms	remaining: 3.88s
# 43:	learn: 0.2534263	total: 376ms	remaining: 3.9s
# 44:	learn: 0.2534223	total: 385ms	remaining: 3.89s
# 45:	learn: 0.2534182	total: 392ms	remaining: 3.87s
# 46:	learn: 0.2534158	total: 400ms	remaining: 3.85s
# 47:	learn: 0.2534117	total: 408ms	remaining: 3.84s
# 48:	learn: 0.2534072	total: 417ms	remaining: 3.84s
# 49:	learn: 0.2534043	total: 425ms	remaining: 3.83s
# 50:	learn: 0.2534003	total: 436ms	remaining: 3.84s
# 51:	learn: 0.2533958	total: 444ms	remaining: 3.83s
# 52:	learn: 0.2533923	total: 454ms	remaining: 3.83s
# 53:	learn: 0.2533885	total: 461ms	remaining: 3.8s
# 54:	learn: 0.2533828	total: 469ms	remaining: 3.79s
# 55:	learn: 0.2533785	total: 476ms	remaining: 3.77s
# 56:	learn: 0.2533739	total: 485ms	remaining: 3.77s
# 57:	learn: 0.2533698	total: 492ms	remaining: 3.75s
# 58:	learn: 0.2533645	total: 500ms	remaining: 3.73s
# 59:	learn: 0.2533594	total: 507ms	remaining: 3.72s
# 60:	learn: 0.2533550	total: 514ms	remaining: 3.7s
# 61:	learn: 0.2533508	total: 521ms	remaining: 3.68s
# 62:	learn: 0.2533482	total: 530ms	remaining: 3.67s
# 63:	learn: 0.2533447	total: 539ms	remaining: 3.67s
# 64:	learn: 0.2533397	total: 548ms	remaining: 3.66s
# 65:	learn: 0.2533364	total: 556ms	remaining: 3.66s
# 66:	learn: 0.2533333	total: 564ms	remaining: 3.65s
# 67:	learn: 0.2533308	total: 572ms	remaining: 3.63s
# 68:	learn: 0.2533272	total: 580ms	remaining: 3.62s
# 69:	learn: 0.2533242	total: 588ms	remaining: 3.61s
# 70:	learn: 0.2533224	total: 596ms	remaining: 3.6s
# 71:	learn: 0.2533187	total: 604ms	remaining: 3.59s
# 72:	learn: 0.2533127	total: 611ms	remaining: 3.57s
# 73:	learn: 0.2533103	total: 620ms	remaining: 3.57s
# 74:	learn: 0.2533043	total: 628ms	remaining: 3.56s
# 75:	learn: 0.2533007	total: 637ms	remaining: 3.55s
# 76:	learn: 0.2532965	total: 645ms	remaining: 3.55s
# 77:	learn: 0.2532942	total: 654ms	remaining: 3.54s
# 78:	learn: 0.2532912	total: 661ms	remaining: 3.52s
# 79:	learn: 0.2532845	total: 669ms	remaining: 3.51s
# 80:	learn: 0.2532803	total: 676ms	remaining: 3.5s
# 81:	learn: 0.2532743	total: 686ms	remaining: 3.49s
# 82:	learn: 0.2532728	total: 693ms	remaining: 3.48s
# 83:	learn: 0.2532701	total: 701ms	remaining: 3.47s
# 84:	learn: 0.2532646	total: 708ms	remaining: 3.45s
# 85:	learn: 0.2532568	total: 716ms	remaining: 3.45s
# 86:	learn: 0.2532546	total: 723ms	remaining: 3.43s
# 87:	learn: 0.2532507	total: 731ms	remaining: 3.42s
# 88:	learn: 0.2532481	total: 737ms	remaining: 3.4s
# 89:	learn: 0.2532448	total: 746ms	remaining: 3.4s
# 90:	learn: 0.2532414	total: 753ms	remaining: 3.38s
# 91:	learn: 0.2532384	total: 762ms	remaining: 3.38s
# 92:	learn: 0.2532352	total: 770ms	remaining: 3.37s
# 93:	learn: 0.2532341	total: 779ms	remaining: 3.37s
# 94:	learn: 0.2532294	total: 788ms	remaining: 3.36s
# 95:	learn: 0.2532254	total: 798ms	remaining: 3.36s
# 96:	learn: 0.2532224	total: 806ms	remaining: 3.35s
# 97:	learn: 0.2532187	total: 815ms	remaining: 3.34s
# 98:	learn: 0.2532139	total: 823ms	remaining: 3.33s
# 99:	learn: 0.2532075	total: 833ms	remaining: 3.33s
# 100:	learn: 0.2532031	total: 844ms	remaining: 3.33s
# 101:	learn: 0.2531998	total: 851ms	remaining: 3.32s
# 102:	learn: 0.2531978	total: 859ms	remaining: 3.31s
# 103:	learn: 0.2531939	total: 866ms	remaining: 3.3s
# 104:	learn: 0.2531888	total: 873ms	remaining: 3.29s
# 105:	learn: 0.2531830	total: 881ms	remaining: 3.27s
# 106:	learn: 0.2531793	total: 888ms	remaining: 3.26s
# 107:	learn: 0.2531753	total: 896ms	remaining: 3.25s
# 108:	learn: 0.2531728	total: 902ms	remaining: 3.24s
# 109:	learn: 0.2531647	total: 910ms	remaining: 3.22s
# 110:	learn: 0.2531619	total: 916ms	remaining: 3.21s
# 111:	learn: 0.2531596	total: 923ms	remaining: 3.2s
# 112:	learn: 0.2531570	total: 932ms	remaining: 3.19s
# 113:	learn: 0.2531533	total: 944ms	remaining: 3.19s
# 114:	learn: 0.2531493	total: 951ms	remaining: 3.18s
# 115:	learn: 0.2531469	total: 958ms	remaining: 3.17s
# 116:	learn: 0.2531392	total: 965ms	remaining: 3.16s
# 117:	learn: 0.2531337	total: 972ms	remaining: 3.15s
# 118:	learn: 0.2531297	total: 980ms	remaining: 3.14s
# 119:	learn: 0.2531239	total: 988ms	remaining: 3.13s
# 120:	learn: 0.2531190	total: 995ms	remaining: 3.12s
# 121:	learn: 0.2531149	total: 1s	remaining: 3.1s
# 122:	learn: 0.2531096	total: 1.01s	remaining: 3.1s
# 123:	learn: 0.2531064	total: 1.02s	remaining: 3.1s
# 124:	learn: 0.2531025	total: 1.03s	remaining: 3.09s
# 125:	learn: 0.2530985	total: 1.04s	remaining: 3.09s
# 126:	learn: 0.2530922	total: 1.06s	remaining: 3.1s
# 127:	learn: 0.2530867	total: 1.07s	remaining: 3.1s
# 128:	learn: 0.2530780	total: 1.08s	remaining: 3.11s
# 129:	learn: 0.2530731	total: 1.09s	remaining: 3.11s
# 130:	learn: 0.2530688	total: 1.1s	remaining: 3.1s
# 131:	learn: 0.2530658	total: 1.11s	remaining: 3.09s
# 132:	learn: 0.2530576	total: 1.11s	remaining: 3.08s
# 133:	learn: 0.2530543	total: 1.12s	remaining: 3.06s
# 134:	learn: 0.2530470	total: 1.13s	remaining: 3.05s
# 135:	learn: 0.2530448	total: 1.14s	remaining: 3.04s
# 136:	learn: 0.2530404	total: 1.14s	remaining: 3.03s
# 137:	learn: 0.2530356	total: 1.15s	remaining: 3.01s
# 138:	learn: 0.2530282	total: 1.16s	remaining: 3.01s
# 139:	learn: 0.2530224	total: 1.16s	remaining: 2.99s
# 140:	learn: 0.2530199	total: 1.17s	remaining: 2.98s
# 141:	learn: 0.2530154	total: 1.18s	remaining: 2.97s
# 142:	learn: 0.2530115	total: 1.18s	remaining: 2.96s
# 143:	learn: 0.2530057	total: 1.19s	remaining: 2.95s
# 144:	learn: 0.2530013	total: 1.2s	remaining: 2.94s
# 145:	learn: 0.2529951	total: 1.21s	remaining: 2.93s
# 146:	learn: 0.2529895	total: 1.21s	remaining: 2.92s
# 147:	learn: 0.2529859	total: 1.22s	remaining: 2.9s
# 148:	learn: 0.2529827	total: 1.23s	remaining: 2.89s
# 149:	learn: 0.2529764	total: 1.24s	remaining: 2.88s
# 150:	learn: 0.2529722	total: 1.24s	remaining: 2.88s
# 151:	learn: 0.2529692	total: 1.25s	remaining: 2.87s
# 152:	learn: 0.2529647	total: 1.26s	remaining: 2.87s
# 153:	learn: 0.2529582	total: 1.28s	remaining: 2.87s
# 154:	learn: 0.2529525	total: 1.29s	remaining: 2.87s
# 155:	learn: 0.2529500	total: 1.3s	remaining: 2.86s
# 156:	learn: 0.2529435	total: 1.31s	remaining: 2.85s
# 157:	learn: 0.2529361	total: 1.31s	remaining: 2.85s
# 158:	learn: 0.2529323	total: 1.32s	remaining: 2.84s
# 159:	learn: 0.2529271	total: 1.33s	remaining: 2.83s
# 160:	learn: 0.2529215	total: 1.34s	remaining: 2.83s
# 161:	learn: 0.2529190	total: 1.35s	remaining: 2.82s
# 162:	learn: 0.2529099	total: 1.36s	remaining: 2.81s
# 163:	learn: 0.2529041	total: 1.37s	remaining: 2.81s
# 164:	learn: 0.2528983	total: 1.38s	remaining: 2.8s
# 165:	learn: 0.2528940	total: 1.39s	remaining: 2.79s
# 166:	learn: 0.2528896	total: 1.4s	remaining: 2.78s
# 167:	learn: 0.2528856	total: 1.4s	remaining: 2.77s
# 168:	learn: 0.2528803	total: 1.41s	remaining: 2.76s
# 169:	learn: 0.2528752	total: 1.42s	remaining: 2.75s
# 170:	learn: 0.2528703	total: 1.43s	remaining: 2.75s
# 171:	learn: 0.2528664	total: 1.43s	remaining: 2.74s
# 172:	learn: 0.2528637	total: 1.44s	remaining: 2.73s
# 173:	learn: 0.2528600	total: 1.45s	remaining: 2.72s
# 174:	learn: 0.2528561	total: 1.46s	remaining: 2.71s
# 175:	learn: 0.2528535	total: 1.47s	remaining: 2.7s
# 176:	learn: 0.2528512	total: 1.48s	remaining: 2.69s
# 177:	learn: 0.2528494	total: 1.48s	remaining: 2.69s
# 178:	learn: 0.2528439	total: 1.49s	remaining: 2.67s
# 179:	learn: 0.2528411	total: 1.5s	remaining: 2.66s
# 180:	learn: 0.2528385	total: 1.51s	remaining: 2.65s
# 181:	learn: 0.2528362	total: 1.51s	remaining: 2.65s
# 182:	learn: 0.2528307	total: 1.52s	remaining: 2.64s
# 183:	learn: 0.2528297	total: 1.53s	remaining: 2.63s
# 184:	learn: 0.2528262	total: 1.54s	remaining: 2.62s
# 185:	learn: 0.2528228	total: 1.54s	remaining: 2.6s
# 186:	learn: 0.2528191	total: 1.55s	remaining: 2.6s
# 187:	learn: 0.2528155	total: 1.56s	remaining: 2.58s
# 188:	learn: 0.2528106	total: 1.57s	remaining: 2.58s
# 189:	learn: 0.2528084	total: 1.57s	remaining: 2.57s
# 190:	learn: 0.2528032	total: 1.58s	remaining: 2.56s
# 191:	learn: 0.2528020	total: 1.59s	remaining: 2.55s
# 192:	learn: 0.2528000	total: 1.59s	remaining: 2.54s
# 193:	learn: 0.2527949	total: 1.6s	remaining: 2.53s
# 194:	learn: 0.2527874	total: 1.61s	remaining: 2.52s
# 195:	learn: 0.2527821	total: 1.62s	remaining: 2.52s
# 196:	learn: 0.2527775	total: 1.64s	remaining: 2.52s
# 197:	learn: 0.2527699	total: 1.64s	remaining: 2.51s
# 198:	learn: 0.2527668	total: 1.66s	remaining: 2.5s
# 199:	learn: 0.2527644	total: 1.67s	remaining: 2.5s
# 200:	learn: 0.2527597	total: 1.67s	remaining: 2.49s
# 201:	learn: 0.2527587	total: 1.68s	remaining: 2.48s
# 202:	learn: 0.2527537	total: 1.69s	remaining: 2.48s
# 203:	learn: 0.2527498	total: 1.7s	remaining: 2.47s
# 204:	learn: 0.2527460	total: 1.71s	remaining: 2.46s
# 205:	learn: 0.2527436	total: 1.72s	remaining: 2.45s
# 206:	learn: 0.2527393	total: 1.72s	remaining: 2.44s
# 207:	learn: 0.2527339	total: 1.73s	remaining: 2.43s
# 208:	learn: 0.2527290	total: 1.74s	remaining: 2.42s
# 209:	learn: 0.2527258	total: 1.74s	remaining: 2.41s
# 210:	learn: 0.2527194	total: 1.75s	remaining: 2.4s
# 211:	learn: 0.2527153	total: 1.76s	remaining: 2.39s
# 212:	learn: 0.2527120	total: 1.76s	remaining: 2.38s
# 213:	learn: 0.2527063	total: 1.77s	remaining: 2.37s
# 214:	learn: 0.2527012	total: 1.78s	remaining: 2.36s
# 215:	learn: 0.2526971	total: 1.79s	remaining: 2.35s
# 216:	learn: 0.2526908	total: 1.8s	remaining: 2.34s
# 217:	learn: 0.2526836	total: 1.8s	remaining: 2.33s
# 218:	learn: 0.2526805	total: 1.81s	remaining: 2.33s
# 219:	learn: 0.2526749	total: 1.82s	remaining: 2.32s
# 220:	learn: 0.2526727	total: 1.83s	remaining: 2.31s
# 221:	learn: 0.2526677	total: 1.83s	remaining: 2.3s
# 222:	learn: 0.2526619	total: 1.84s	remaining: 2.29s
# 223:	learn: 0.2526589	total: 1.85s	remaining: 2.29s
# 224:	learn: 0.2526537	total: 1.87s	remaining: 2.28s
# 225:	learn: 0.2526502	total: 1.89s	remaining: 2.29s
# 226:	learn: 0.2526466	total: 1.91s	remaining: 2.3s
# 227:	learn: 0.2526426	total: 1.93s	remaining: 2.31s
# 228:	learn: 0.2526375	total: 1.94s	remaining: 2.3s
# 229:	learn: 0.2526282	total: 1.95s	remaining: 2.29s
# 230:	learn: 0.2526242	total: 1.97s	remaining: 2.29s
# 231:	learn: 0.2526178	total: 1.98s	remaining: 2.28s
# 232:	learn: 0.2526124	total: 1.99s	remaining: 2.28s
# 233:	learn: 0.2526094	total: 2s	remaining: 2.27s
# 234:	learn: 0.2526069	total: 2.01s	remaining: 2.27s
# 235:	learn: 0.2526051	total: 2.02s	remaining: 2.27s
# 236:	learn: 0.2525997	total: 2.04s	remaining: 2.26s
# 237:	learn: 0.2525935	total: 2.05s	remaining: 2.26s
# 238:	learn: 0.2525900	total: 2.06s	remaining: 2.25s
# 239:	learn: 0.2525860	total: 2.08s	remaining: 2.25s
# 240:	learn: 0.2525805	total: 2.09s	remaining: 2.25s
# 241:	learn: 0.2525756	total: 2.11s	remaining: 2.25s
# 242:	learn: 0.2525740	total: 2.12s	remaining: 2.25s
# 243:	learn: 0.2525723	total: 2.14s	remaining: 2.24s
# 244:	learn: 0.2525701	total: 2.15s	remaining: 2.24s
# 245:	learn: 0.2525652	total: 2.16s	remaining: 2.23s
# 246:	learn: 0.2525600	total: 2.16s	remaining: 2.22s
# 247:	learn: 0.2525541	total: 2.17s	remaining: 2.21s
# 248:	learn: 0.2525495	total: 2.18s	remaining: 2.2s
# 249:	learn: 0.2525464	total: 2.19s	remaining: 2.19s
# 250:	learn: 0.2525419	total: 2.2s	remaining: 2.18s
# 251:	learn: 0.2525382	total: 2.2s	remaining: 2.17s
# 252:	learn: 0.2525361	total: 2.21s	remaining: 2.16s
# 253:	learn: 0.2525323	total: 2.22s	remaining: 2.15s
# 254:	learn: 0.2525267	total: 2.23s	remaining: 2.14s
# 255:	learn: 0.2525246	total: 2.23s	remaining: 2.13s
# 256:	learn: 0.2525216	total: 2.24s	remaining: 2.12s
# 257:	learn: 0.2525161	total: 2.25s	remaining: 2.11s
# 258:	learn: 0.2525125	total: 2.26s	remaining: 2.1s
# 259:	learn: 0.2525096	total: 2.27s	remaining: 2.09s
# 260:	learn: 0.2525062	total: 2.28s	remaining: 2.09s
# 261:	learn: 0.2525037	total: 2.29s	remaining: 2.08s
# 262:	learn: 0.2524994	total: 2.3s	remaining: 2.07s
# 263:	learn: 0.2524948	total: 2.31s	remaining: 2.06s
# 264:	learn: 0.2524918	total: 2.32s	remaining: 2.05s
# 265:	learn: 0.2524884	total: 2.33s	remaining: 2.05s
# 266:	learn: 0.2524841	total: 2.33s	remaining: 2.04s
# 267:	learn: 0.2524803	total: 2.34s	remaining: 2.03s
# 268:	learn: 0.2524772	total: 2.35s	remaining: 2.02s
# 269:	learn: 0.2524760	total: 2.36s	remaining: 2.01s
# 270:	learn: 0.2524716	total: 2.37s	remaining: 2s
# 271:	learn: 0.2524671	total: 2.37s	remaining: 1.99s
# 272:	learn: 0.2524619	total: 2.38s	remaining: 1.98s
# 273:	learn: 0.2524583	total: 2.39s	remaining: 1.97s
# 274:	learn: 0.2524478	total: 2.4s	remaining: 1.96s
# 275:	learn: 0.2524440	total: 2.4s	remaining: 1.95s
# 276:	learn: 0.2524402	total: 2.41s	remaining: 1.94s
# 277:	learn: 0.2524358	total: 2.42s	remaining: 1.93s
# 278:	learn: 0.2524314	total: 2.43s	remaining: 1.92s
# 279:	learn: 0.2524291	total: 2.43s	remaining: 1.91s
# 280:	learn: 0.2524277	total: 2.44s	remaining: 1.9s
# 281:	learn: 0.2524230	total: 2.45s	remaining: 1.89s
# 282:	learn: 0.2524189	total: 2.45s	remaining: 1.88s
# 283:	learn: 0.2524129	total: 2.46s	remaining: 1.87s
# 284:	learn: 0.2524071	total: 2.47s	remaining: 1.86s
# 285:	learn: 0.2524030	total: 2.48s	remaining: 1.85s
# 286:	learn: 0.2523994	total: 2.49s	remaining: 1.84s
# 287:	learn: 0.2523958	total: 2.49s	remaining: 1.83s
# 288:	learn: 0.2523934	total: 2.5s	remaining: 1.82s
# 289:	learn: 0.2523897	total: 2.51s	remaining: 1.81s
# 290:	learn: 0.2523865	total: 2.51s	remaining: 1.8s
# 291:	learn: 0.2523814	total: 2.52s	remaining: 1.79s
# 292:	learn: 0.2523765	total: 2.53s	remaining: 1.78s
# 293:	learn: 0.2523715	total: 2.53s	remaining: 1.77s
# 294:	learn: 0.2523686	total: 2.54s	remaining: 1.77s
# 295:	learn: 0.2523631	total: 2.55s	remaining: 1.76s
# 296:	learn: 0.2523567	total: 2.56s	remaining: 1.75s
# 297:	learn: 0.2523535	total: 2.56s	remaining: 1.74s
# 298:	learn: 0.2523489	total: 2.57s	remaining: 1.73s
# 299:	learn: 0.2523431	total: 2.58s	remaining: 1.72s
# 300:	learn: 0.2523394	total: 2.59s	remaining: 1.71s
# 301:	learn: 0.2523376	total: 2.6s	remaining: 1.7s
# 302:	learn: 0.2523352	total: 2.61s	remaining: 1.69s
# 303:	learn: 0.2523347	total: 2.61s	remaining: 1.69s
# 304:	learn: 0.2523314	total: 2.62s	remaining: 1.68s
# 305:	learn: 0.2523277	total: 2.63s	remaining: 1.67s
# 306:	learn: 0.2523253	total: 2.64s	remaining: 1.66s
# 307:	learn: 0.2523214	total: 2.64s	remaining: 1.65s
# 308:	learn: 0.2523168	total: 2.65s	remaining: 1.64s
# 309:	learn: 0.2523127	total: 2.66s	remaining: 1.63s
# 310:	learn: 0.2523099	total: 2.67s	remaining: 1.62s
# 311:	learn: 0.2523069	total: 2.68s	remaining: 1.61s
# 312:	learn: 0.2523036	total: 2.69s	remaining: 1.6s
# 313:	learn: 0.2522989	total: 2.75s	remaining: 1.63s
# 314:	learn: 0.2522963	total: 2.76s	remaining: 1.62s
# 315:	learn: 0.2522923	total: 2.77s	remaining: 1.61s
# 316:	learn: 0.2522882	total: 2.78s	remaining: 1.61s
# 317:	learn: 0.2522873	total: 2.79s	remaining: 1.6s
# 318:	learn: 0.2522823	total: 2.8s	remaining: 1.59s
# 319:	learn: 0.2522775	total: 2.8s	remaining: 1.58s
# 320:	learn: 0.2522753	total: 2.81s	remaining: 1.57s
# 321:	learn: 0.2522728	total: 2.82s	remaining: 1.56s
# 322:	learn: 0.2522684	total: 2.83s	remaining: 1.55s
# 323:	learn: 0.2522631	total: 2.84s	remaining: 1.54s
# 324:	learn: 0.2522605	total: 2.84s	remaining: 1.53s
# 325:	learn: 0.2522551	total: 2.85s	remaining: 1.52s
# 326:	learn: 0.2522545	total: 2.86s	remaining: 1.51s
# 327:	learn: 0.2522450	total: 2.87s	remaining: 1.5s
# 328:	learn: 0.2522411	total: 2.88s	remaining: 1.5s
# 329:	learn: 0.2522385	total: 2.89s	remaining: 1.49s
# 330:	learn: 0.2522343	total: 2.9s	remaining: 1.48s
# 331:	learn: 0.2522280	total: 2.91s	remaining: 1.47s
# 332:	learn: 0.2522250	total: 2.92s	remaining: 1.46s
# 333:	learn: 0.2522222	total: 2.92s	remaining: 1.45s
# 334:	learn: 0.2522195	total: 2.93s	remaining: 1.44s
# 335:	learn: 0.2522163	total: 2.94s	remaining: 1.43s
# 336:	learn: 0.2522119	total: 2.95s	remaining: 1.43s
# 337:	learn: 0.2522073	total: 2.96s	remaining: 1.42s
# 338:	learn: 0.2522049	total: 2.96s	remaining: 1.41s
# 339:	learn: 0.2522027	total: 2.97s	remaining: 1.4s
# 340:	learn: 0.2521990	total: 2.98s	remaining: 1.39s
# 341:	learn: 0.2521932	total: 2.98s	remaining: 1.38s
# 342:	learn: 0.2521905	total: 2.99s	remaining: 1.37s
# 343:	learn: 0.2521846	total: 3s	remaining: 1.36s
# 344:	learn: 0.2521818	total: 3s	remaining: 1.35s
# 345:	learn: 0.2521771	total: 3.01s	remaining: 1.34s
# 346:	learn: 0.2521731	total: 3.02s	remaining: 1.33s
# 347:	learn: 0.2521699	total: 3.03s	remaining: 1.32s
# 348:	learn: 0.2521654	total: 3.04s	remaining: 1.31s
# 349:	learn: 0.2521585	total: 3.04s	remaining: 1.3s
# 350:	learn: 0.2521547	total: 3.05s	remaining: 1.29s
# 351:	learn: 0.2521531	total: 3.06s	remaining: 1.28s
# 352:	learn: 0.2521497	total: 3.06s	remaining: 1.28s
# 353:	learn: 0.2521457	total: 3.07s	remaining: 1.27s
# 354:	learn: 0.2521422	total: 3.08s	remaining: 1.26s
# 355:	learn: 0.2521360	total: 3.09s	remaining: 1.25s
# 356:	learn: 0.2521329	total: 3.1s	remaining: 1.24s
# 357:	learn: 0.2521282	total: 3.11s	remaining: 1.23s
# 358:	learn: 0.2521246	total: 3.12s	remaining: 1.22s
# 359:	learn: 0.2521231	total: 3.12s	remaining: 1.21s
# 360:	learn: 0.2521188	total: 3.13s	remaining: 1.21s
# 361:	learn: 0.2521133	total: 3.14s	remaining: 1.2s
# 362:	learn: 0.2521080	total: 3.15s	remaining: 1.19s
# 363:	learn: 0.2521033	total: 3.15s	remaining: 1.18s
# 364:	learn: 0.2521002	total: 3.16s	remaining: 1.17s
# 365:	learn: 0.2520930	total: 3.17s	remaining: 1.16s
# 366:	learn: 0.2520860	total: 3.18s	remaining: 1.15s
# 367:	learn: 0.2520834	total: 3.19s	remaining: 1.14s
# 368:	learn: 0.2520815	total: 3.19s	remaining: 1.13s
# 369:	learn: 0.2520786	total: 3.2s	remaining: 1.12s
# 370:	learn: 0.2520742	total: 3.21s	remaining: 1.11s
# 371:	learn: 0.2520714	total: 3.21s	remaining: 1.11s
# 372:	learn: 0.2520678	total: 3.22s	remaining: 1.1s
# 373:	learn: 0.2520638	total: 3.23s	remaining: 1.09s
# 374:	learn: 0.2520610	total: 3.24s	remaining: 1.08s
# 375:	learn: 0.2520568	total: 3.25s	remaining: 1.07s
# 376:	learn: 0.2520519	total: 3.25s	remaining: 1.06s
# 377:	learn: 0.2520492	total: 3.26s	remaining: 1.05s
# 378:	learn: 0.2520434	total: 3.27s	remaining: 1.04s
# 379:	learn: 0.2520403	total: 3.28s	remaining: 1.03s
# 380:	learn: 0.2520362	total: 3.29s	remaining: 1.03s
# 381:	learn: 0.2520301	total: 3.29s	remaining: 1.02s
# 382:	learn: 0.2520255	total: 3.3s	remaining: 1.01s
# 383:	learn: 0.2520223	total: 3.31s	remaining: 999ms
# 384:	learn: 0.2520186	total: 3.31s	remaining: 990ms
# 385:	learn: 0.2520115	total: 3.32s	remaining: 981ms
# 386:	learn: 0.2520077	total: 3.33s	remaining: 972ms
# 387:	learn: 0.2520010	total: 3.34s	remaining: 963ms
# 388:	learn: 0.2519984	total: 3.34s	remaining: 954ms
# 389:	learn: 0.2519924	total: 3.35s	remaining: 945ms
# 390:	learn: 0.2519885	total: 3.36s	remaining: 937ms
# 391:	learn: 0.2519831	total: 3.37s	remaining: 928ms
# 392:	learn: 0.2519780	total: 3.38s	remaining: 919ms
# 393:	learn: 0.2519730	total: 3.38s	remaining: 910ms
# 394:	learn: 0.2519707	total: 3.39s	remaining: 901ms
# 395:	learn: 0.2519677	total: 3.4s	remaining: 892ms
sinker_23['pred'] = sinker_model.predict(sinker_23[features])

cutter_23['pred'] = cutter_model.predict(cutter_23[features])

slider_23['pred'] = slider_model.predict(slider_23[features])

sweeper_23['pred'] = sweeper_model.predict(sweeper_23[features])

curveball_23['pred'] = curveball_model.predict(curveball_23[features])

changeup_23['pred'] = changeup_model.predict(changeup_23[features])

splitter_23['pred'] = splitter_model.predict(splitter_23[features])
# Out:
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/2925554147.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fastball_23['pred'] = fastball_model.predict(fastball_23[features])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/2925554147.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sinker_23['pred'] = sinker_model.predict(sinker_23[features])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/2925554147.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cutter_23['pred'] = cutter_model.predict(cutter_23[features])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/2925554147.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slider_23['pred'] = slider_model.predict(slider_23[features])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/2925554147.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sweeper_23['pred'] = sweeper_model.predict(sweeper_23[features])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/2925554147.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curveball_23['pred'] = curveball_model.predict(curveball_23[features])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/2925554147.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   changeup_23['pred'] = changeup_model.predict(changeup_23[features])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/2925554147.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   splitter_23['pred'] = splitter_model.predict(splitter_23[features])

# %%
def scale_and_score(df):
    df['scaled'] = df['pred'] - df['pred'].max()
    df['scaled'] = abs(df['scaled'])
    df['scaled'] = df['scaled'] - df['scaled'].mean()
    df['scaled'] = df['scaled'] / df['scaled'].std()
    df['score'] = df['scaled'] * 10 + 100
    return df

scale_and_score(fastball_23)
scale_and_score(sinker_23)
scale_and_score(cutter_23)
scale_and_score(slider_23)
scale_and_score(sweeper_23)
scale_and_score(curveball_23)
scale_and_score(changeup_23)
scale_and_score(splitter_23)

def calculate_mean_scores(df):
    mean_scores = df.groupby('player_name')['score'].mean().reset_index()
    mean_scores.rename(columns={'score': 'mean_scores'}, inplace=True)
    mean_scores = mean_scores.sort_values(by='mean_scores', ascending=False)
    mean_scores['mean_scores'] = mean_scores['mean_scores'].round(2)
    return mean_scores

mean_scores_fastball = calculate_mean_scores(fastball_23)
mean_scores_sinker = calculate_mean_scores(sinker_23)
mean_scores_cutter = calculate_mean_scores(cutter_23)
mean_scores_slider = calculate_mean_scores(slider_23)
mean_scores_sweeper = calculate_mean_scores(sweeper_23)
mean_scores_curveball = calculate_mean_scores(curveball_23)
mean_scores_changeup = calculate_mean_scores(changeup_23)
mean_scores_splitter = calculate_mean_scores(splitter_23)

combined_scores = mean_scores_fastball
combined_scores = combined_scores.merge(mean_scores_sinker, how = 'left', on = 'player_name', suffixes=('','_sinker'))
combined_scores = combined_scores.merge(mean_scores_cutter, how = 'left', on = 'player_name', suffixes=('','_cutter'))
combined_scores = combined_scores.merge(mean_scores_slider, how = 'left', on = 'player_name', suffixes=('','_slider'))
combined_scores = combined_scores.merge(mean_scores_sweeper, how = 'left', on = 'player_name', suffixes=('','_sweeper'))
combined_scores = combined_scores.merge(mean_scores_curveball, how = 'left', on = 'player_name', suffixes=('','_curveball'))
combined_scores = combined_scores.merge(mean_scores_changeup, how = 'left', on = 'player_name', suffixes=('','_changeup'))
combined_scores = combined_scores.merge(mean_scores_splitter, how = 'left', on = 'player_name', suffixes=('','_splitter'))



combined_scores = combined_scores.rename(columns = {
    'mean_scores': 'fastball',
    'mean_scores_sinker': 'sinker',
    'mean_scores_cutter': 'cutter',
    'mean_scores_slider': 'slider',
    'mean_scores_sweeper': 'sweeper',
    'mean_scores_curveball': 'curveball',
    'mean_scores_changeup': 'changeup',
    'mean_scores_splitter': 'splitter'
    }
)

pitch_counts = data_today.groupby(['player_name', 'pitch_type']).size().unstack(fill_value=0).reset_index()

combined_data = combined_scores.merge(pitch_counts, how='left', on='player_name')
combined_data.fillna(0, inplace=True)

combined_data['weighted_fastball'] = combined_data['fastball'] * combined_data['Fastball']
combined_data['weighted_sinker'] = combined_data['sinker'] * combined_data['Sinker']
combined_data['weighted_cutter'] = combined_data['cutter'] * combined_data['Cutter']
combined_data['weighted_slider'] = combined_data['slider'] * combined_data['Slider']
combined_data['weighted_sweeper'] = combined_data['sweeper'] * combined_data['Sweeper']
combined_data['weighted_curveball'] = combined_data['curveball'] * combined_data['Curveball']
combined_data['weighted_changeup'] = combined_data['changeup'] * combined_data['Changeup']
combined_data['weighted_splitter'] = combined_data['splitter'] * combined_data['Splitter']

combined_data['total_weighted_score'] = (
    combined_data['weighted_fastball'] +
    combined_data['weighted_sinker'] +
    combined_data['weighted_cutter'] +
    combined_data['weighted_slider'] +
    combined_data['weighted_sweeper'] +
    combined_data['weighted_curveball'] +
    combined_data['weighted_changeup'] +
    combined_data['weighted_splitter']
)

combined_data['total_pitches'] = (
    combined_data['Fastball'] +
    combined_data['Sinker'] +
    combined_data['Cutter'] +
    combined_data['Slider'] +
    combined_data['Sweeper'] +
    combined_data['Curveball'] +
    combined_data['Changeup'] +
    combined_data['Splitter']
)

combined_data['overall'] = combined_data['total_weighted_score'] / combined_data['total_pitches']

combined_data['overall'] = combined_data['overall'].round(2)

combined_data = combined_data[['player_name', 'overall', 'fastball', 'sinker', 'cutter', 'slider', 'sweeper', 'curveball', 'changeup', 'splitter']]

combined_data = combined_data.sort_values(by='overall', ascending=False)

combined_data.to_csv("day_pitch_scores.csv", index=False)
combined_data
# Out:
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['pred'] - df['pred'].max()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = abs(df['scaled'])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] - df['scaled'].mean()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] / df['scaled'].std()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'] = df['scaled'] * 10 + 100
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['pred'] - df['pred'].max()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = abs(df['scaled'])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] - df['scaled'].mean()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] / df['scaled'].std()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'] = df['scaled'] * 10 + 100
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['pred'] - df['pred'].max()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = abs(df['scaled'])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] - df['scaled'].mean()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] / df['scaled'].std()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'] = df['scaled'] * 10 + 100
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['pred'] - df['pred'].max()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = abs(df['scaled'])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] - df['scaled'].mean()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] / df['scaled'].std()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'] = df['scaled'] * 10 + 100
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['pred'] - df['pred'].max()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = abs(df['scaled'])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] - df['scaled'].mean()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] / df['scaled'].std()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'] = df['scaled'] * 10 + 100
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['pred'] - df['pred'].max()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = abs(df['scaled'])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] - df['scaled'].mean()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] / df['scaled'].std()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'] = df['scaled'] * 10 + 100
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['pred'] - df['pred'].max()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = abs(df['scaled'])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] - df['scaled'].mean()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] / df['scaled'].std()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'] = df['scaled'] * 10 + 100
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['pred'] - df['pred'].max()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = abs(df['scaled'])
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] - df['scaled'].mean()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scaled'] = df['scaled'] / df['scaled'].std()
# /var/folders/8n/cvy2zw5j013f0b4bj6srsd880000gn/T/ipykernel_47979/705413268.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'] = df['scaled'] * 10 + 100
#         player_name  overall  fastball  sinker  cutter  slider  sweeper  \
# 42     Jax, Griffin   114.62     99.46  116.70    0.00    0.00   105.38
# 1   Fairbanks, Pete   112.30    109.53    0.00    0.00  117.84     0.00
# 33      Díaz, Edwin   110.98    101.01    0.00    0.00  119.70     0.00
# 0       Vesia, Alex   109.14    112.26    0.00    0.00  101.34     0.00
# 19    Alcala, Jorge   108.30    102.92  124.71    0.00  110.94     0.00
# ..              ...      ...       ...     ...     ...     ...      ...
# 60    Ginkel, Kevin    95.51     95.56   95.36    0.00    0.00     0.00
# 18  Fernandez, Ryan    94.20    102.95   89.49    0.00   96.62     0.00
# 30  Schreiber, John    92.57    101.30  116.14   50.15    0.00    60.65
# 67   Muñoz, Roddery    92.00     87.52   91.04   98.62   85.03     0.00
# 68  Yarbrough, Ryan    83.30     44.04   87.82   90.40    0.00     0.00
#
#     curveball  changeup  splitter
# 42       0.00    131.04       0.0
# 1        0.00      0.00       0.0
# 33       0.00      0.00       0.0
# 0        0.00      0.00       0.0
# 19       0.00      0.00       0.0
# ..        ...       ...       ...
# 60       0.00      0.00       0.0
# 18       0.00      0.00       0.0
# 30       0.00     97.17       0.0
# 67       0.00     78.96       0.0
# 68     101.56     73.65       0.0
#
# [69 rows x 10 columns]

# %%
def get_top_individual_pitches(pitch_df, pitch_type):
    top_pitches = pitch_df[['player_name', 'pitch_type', 'release_speed','release_pos_x','release_pos_z','release_extension','pfx_x', 'pfx_z','score']]
    top_pitches = top_pitches.sort_values(by='score', ascending=False)
    top_pitches['pitch_type'] = pitch_type
    return top_pitches

top_fastball_pitches = get_top_individual_pitches(fastball_23, 'Fastball')
top_sinker_pitches = get_top_individual_pitches(sinker_23, 'Sinker')
top_cutter_pitches = get_top_individual_pitches(cutter_23, 'Cutter')
top_slider_pitches = get_top_individual_pitches(slider_23, 'Slider')
top_sweeper_pitches = get_top_individual_pitches(sweeper_23, 'Sweeper')
top_curveball_pitches = get_top_individual_pitches(curveball_23, 'Curveball')
top_changeup_pitches = get_top_individual_pitches(changeup_23, 'Changeup')
top_splitter_pitches = get_top_individual_pitches(splitter_23, 'Splitter')

top_individual_pitches = pd.concat([
    top_fastball_pitches,
    top_sinker_pitches,
    top_cutter_pitches,
    top_slider_pitches,
    top_sweeper_pitches,
    top_curveball_pitches,
    top_changeup_pitches,
    top_splitter_pitches
])
top_individual_pitches = top_individual_pitches.sort_values(by='score', ascending=False)

top_individual_pitches.to_csv("top_individual_pitches.csv", index=False)
top_individual_pitches
# Out:
#           player_name pitch_type  release_speed  release_pos_x  release_pos_z  \
# 2882    Miller, Tyson    Sweeper           79.4          -3.76           4.55
# 2881    Miller, Tyson    Sweeper           79.2          -3.93           4.55
# 1192     Holmes, Clay     Sinker           97.3          -0.82           6.37
# 1757     Jax, Griffin   Changeup           93.7          -0.63           5.56
# 1680  Yarbrough, Ryan  Curveball           71.7           3.45           4.74
# ...               ...        ...            ...            ...            ...
# 1253  Schreiber, John     Cutter           89.3          -2.64           4.07
# 1640  Yarbrough, Ryan  Curveball           72.7           3.46           4.56
# 1659  Yarbrough, Ryan   Fastball           87.1           3.26           4.88
# 1653  Yarbrough, Ryan   Fastball           87.7           3.15           4.92
# 1684  Yarbrough, Ryan   Fastball           87.1           3.26           4.94
#
#       release_extension  pfx_x  pfx_z       score
# 2882                7.4 -11.52  12.84  151.355746
# 2881                7.0  -12.0   12.0  149.255295
# 1192                6.1  19.44   1.44  140.318599
# 1757                6.4  16.92   1.08  139.602990
# 1680                6.2  16.08   9.84  137.635692
# ...                 ...    ...    ...         ...
# 1253                6.5   7.68   5.52   16.574287
# 1640                6.5  17.76   7.44    7.725568
# 1659                6.2  -14.4   6.84    3.789172
# 1653                6.4  -15.6   7.56   -6.310349
# 1684                6.2 -15.96   6.48  -61.779081
#
# [3102 rows x 9 columns]
